# %% [markdown]
# # Plotting Notebook
# This notebook displays and manipulates the histograms produced by `make_plots.py`. <br>
# Please use this is a guide to the type plots that you can create, as examples of the `hist`, `mplhep`, and other packages, as well as the use of the various functions that we have written in `plot_utils.py`. <br>
# Use the the Table of Contents in Jupyter to view the different sections of the notebook to help navigating it.

# %%
# %load_ext autoreload

# %%
# %autoreload 1

# %%
import os, sys, glob
import pickle
import math
import itertools
import warnings
import json
import numpy as np
from typing import Dict, List
from rich.pretty import pprint
from rich.console import Console
from rich.table import Table
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib
import hist
from hist import Hist
import mplhep as hep
from tabulate import tabulate
import scipy
# %aimport plot_utils
# %aimport plot_utils_extras
# %aimport fill_utils

warnings.filterwarnings('ignore')
matplotlib.rcParams.update({'figure.max_open_warning': 0})
matplotlib.rcParams['figure.facecolor'] = 'white'
plt.style.use(hep.style.CMS)

# %%
print("The following output directories are available:")
# !ls | grep output_histograms
# Out:
# The following output directories are available:
# CR_cb_34mu_output_histograms
# CR_cb_combine_output_histograms
# CR_cb_output_histograms
# CR_cb_postDYstudy_output_histograms
# CR_light_postDYstudy_output_histograms
# CR_prompt_34mu_leading_output_histograms
# CR_prompt_34mu_output_histograms
# CR_prompt_combine_output_histograms
# CR_prompt_dimuon_output_histograms
# CR_prompt_dystudy_output_histograms
# CR_prompt_leading_output_histograms
# CR_prompt_output_histograms
# CR_prompt_postDYstudy_output_histograms
# DYstudy_2_output_histograms
# DYstudy_3_output_histograms
# DYstudy_4_output_histograms
# DYstudy_5_output_histograms
# DYstudy_output_histograms
# DYstudy_trigger_match_double_output_histograms
# DYstudy_trigger_match_triple_output_histograms
# DYstudy_trigger_one_path_output_histograms
# nbjet_comparison_output_histograms
# SR_combine_new_trigger_output_histograms
# SR_combine_output_histograms
# SR_extrapolation_output_histograms
# SR_postDYstudy_output_histograms
# temp_output_histograms

# %% [markdown]
# ## Notebook Parameters
# The following couple cells define the input and output directories, and load in the desired .pkl files into the `plots` nested dictionary.<br>
# `output_label`: _str_, saves plots as `<output_label>+<plot_name>.<file_ext>`.<br>
# `file_ext`: _str_, see above.<br>

# %%
# parameters
output_label = './output_plots/'
file_ext = '.png'

# %% [markdown]
# The `plots` dictionary is used to store all the plots imported from the pickle files. Dimensions: (sample) x (plot label) <br>
# The `loader` function in `plot_utils.py` automatically merges all the QCD HT and QCD pT bins into one sample ('QCD_HT' and 'QCD_Pt'), applies the lumis, and excludes some of the low QCD bins.<br>

# %%
# create output dir
if not os.path.isdir(output_label): 
    print("Creating", output_label)
    os.mkdir(output_label)

# This part is meant to be flxeible, depending on what you want to import
# dimensions of plots: (sample) x (plot label)
# N.B.: lumis are applied through loader()

# input .pkl files
plotDir = './SR_combine_new_trigger_output_histograms/'
infile_names = glob.glob(plotDir+'*.pkl')

# generate list of files that you want to merge histograms for
offline_files_SUEP = [
    f for f in infile_names if ("SUEP" in f) and ("histograms.pkl" in f)
]
offline_files_normalized = [
    f for f in infile_names if ("normalized.pkl" in f)
]
offline_files_other = [
    f for f in infile_names if ("pythia8" in f) and ("histograms.pkl" in f)
]
offline_files = offline_files_normalized + offline_files_other
pprint(offline_files)

other_bkg_names = {
    "DY0JetsToLL": "DY0JetsToLL_M-50_TuneCP5_13TeV-amcatnloFXFX-pythia8",
    "DYJetsToLL_NLO": "DYJetsToLL_M-50_TuneCP5_13TeV-amcatnloFXFX-pythia8",
    "DYLowMass_NLO": "DYJetsToLL_M-10to50_TuneCP5_13TeV-amcatnloFXFX-pythia8+"
                     "RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v2+MINIAODSIM",
    "DYLowMass_LO": "DYJetsToLL_M-10to50_TuneCP5_13TeV-madgraphMLM-pythia8+"
                    "RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v1+MINIAODSIM",
    "TTJets": "TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8+"
              "RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v2+MINIAODSIM",
    "ttZJets": "ttZJets_TuneCP5_13TeV_madgraphMLM_pythia8+"
               "RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v2+MINIAODSIM",
    "WWZ_4F": "WWZ_4F_TuneCP5_13TeV-amcatnlo-pythia8+"
              "RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1_ext1-v2+MINIAODSIM",
    "ZZTo4L": "ZZTo4L_TuneCP5_13TeV_powheg_pythia8+"
              "RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1-v2+MINIAODSIM",
    "ZZZ": "ZZZ_TuneCP5_13TeV-amcatnlo-pythia8+"
           "RunIISummer20UL18MiniAODv2-106X_upgrade2018_realistic_v16_L1v1_ext1-v2+MINIAODSIM",
    "WJets_inclusive": "WJetsToLNu_TuneCP5_13TeV-amcatnloFXFX-pythia8+"
                 "RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM",
    "ST_tW": "ST_tW_Dilept_5f_DR_TuneCP5_13TeV-amcatnlo-pythia8+"
             "RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM"
}

# merge the histograms, apply lumis, exclude low HT bins
plots_SUEP_2018 = plot_utils.loader(offline_files_SUEP, year=2018)
plots_2018 = plot_utils.loader(offline_files, year=2018)
#plots_data = plot_utils.loader(data_files, year=2018, is_data=True)

# put everything in one dictionary, apply lumi for SUEPs
plots = {}
for key in plots_SUEP_2018.keys():
    tag = ""
    if "SUEP-m" in key:
        tag = "+RunIIAutumn18-private+MINIAODSIM"
    plots[key + "_2018"] = fill_utils.apply_normalization(
        plots_SUEP_2018[key],
        fill_utils.getXSection(
            key + tag, "2018", SUEP=True
        ),
    )
for key in plots_2018.keys():
    is_binned = False
    binned_samples = [
        "QCD_Pt",
        "WJetsToLNu_HT",
        "WZTo",
        "WZ_all",
        "WWTo",
        "WW_all",
        "ST_t-channel",
        "JetsToLL_M-50_TuneCP5_13TeV-madgraphMLM-pythia8",
        "DYNJetsToLL",
    ]
    for binned_sample in binned_samples:
        if binned_sample in key:
            is_binned = True
    if is_binned and ("normalized" not in key) and ("cutflow" in key):
        continue
    if is_binned or ("bkg" in key):
        plots[key + "_2018"] = plots_2018[key]
    else:
        plots[key + "_2018"] = fill_utils.apply_normalization(
            plots_2018[key],
            fill_utils.getXSection(other_bkg_names[key], "2018", SUEP=False),
        )

# Combine DYJetsToLL_NLO with DYLowMass_NLO
dy_nlo_all = {}
for plt_i in plots["DYLowMass_NLO_2018"].keys():
    dy_nlo_all[plt_i] = (
        plots["DYLowMass_NLO_2018"][plt_i] + plots["DYJetsToLL_NLO_2018"][plt_i]
    )
plots["DY_NLO_all_2018"] = dy_nlo_all

# Combine ZZZ with WWZ
vvv_combined = {}
for plt_i in plots["WWZ_4F_2018"].keys():
    vvv_combined[plt_i] = plots["WWZ_4F_2018"][plt_i] + plots["ZZZ_2018"][plt_i]
plots["VVV_2018"] = vvv_combined

# Combine ZZ, WZ, and WW
vv_combined = {}
for plt_i in plots["WZ_all_2018"].keys():
    vv_combined[plt_i] = (
        plots["WW_all_2018"][plt_i]
        + plots["WZ_all_2018"][plt_i]
        + plots["ZZTo4L_2018"][plt_i]
    )
plots["VV_2018"] = vv_combined

# Combine ST
st_combined = {}
for plt_i in plots["ST_t-channel_2018"].keys():
    st_combined[plt_i] = (
        plots["ST_t-channel_2018"][plt_i] + plots["ST_tW_2018"][plt_i]
    )
plots["ST_2018"] = st_combined

# Combine WJetsHT and WJets_inclusive
wjets_combined = {}
for plt_i in plots["WJetsToLNu_HT_2018"].keys():
    wjets_combined[plt_i] = (
        plots["WJetsToLNu_HT_2018"][plt_i] + plots["WJets_inclusive_2018"][plt_i]
    )
plots["WJets_all_2018"] = wjets_combined

# Normalize QCD MuEnriched if it exists
if "QCD_Pt_MuEnriched_2018" in plots.keys():
    for plot in plots["QCD_Pt_MuEnriched_2018"].keys():
        plots["QCD_Pt_MuEnriched_2018"][plot] = plots["QCD_Pt_MuEnriched_2018"][
            plot
        ]
# Out:
# [
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-120To170_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-15To20_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-170To300_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-20To30_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-300To470_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-30To50_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-470To600_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-50To80_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-600To800_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-800To1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-80To120_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/ST_t-channel_antitop_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/ST_t-channel_top_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-1200To2500_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-2500ToInf_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-600To800_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-70To100_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WWTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WWTo2L2Nu_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo1L3Nu_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo2Q2L_mllmin4p0_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo3LNu_mllmin4p0_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized.pkl',
# │   './SR_combine_new_trigger_output_histograms/DYJetsToLL_M-10to50_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/ST_t-channel_antitop_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/ST_t-channel_top_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/ST_tW_Dilept_5f_DR_TuneCP5_13TeV-amcatnlo-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-1200To2500_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-2500ToInf_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-600To800_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-70To100_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WJetsToLNu_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WWTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WWTo2L2Nu_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo1L3Nu_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo2Q2L_mllmin4p0_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WZTo3LNu_mllmin4p0_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/DYJetsToLL_M-50_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-120To170_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-15To20_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-170To300_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-20To30_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-300To470_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-30To50_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-470To600_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-50To80_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-600To800_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-800To1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/QCD_Pt-80To120_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/ttZJets_TuneCP5_13TeV_madgraphMLM_pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/WWZ_4F_TuneCP5_13TeV-amcatnlo-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1_ext1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/ZZTo4L_TuneCP5_13TeV_powheg_pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms.pkl',
# │   './SR_combine_new_trigger_output_histograms/ZZZ_TuneCP5_13TeV-amcatnlo-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1_ext1-v2+NANOAODSIM_histograms.pkl'
# ]

# %% [markdown]
# These are all the samples loaded.

# %%
keys = list(plots.keys())
pprint(keys)
# Out:
# [
# │   'SUEP-m125-darkPho_2018',
# │   'SUEP-m125-darkPhoHad_2018',
# │   'SUEP-m400-darkPho_2018',
# │   'SUEP-m400-darkPhoHad_2018',
# │   'SUEP-m750-darkPho_2018',
# │   'SUEP-m750-darkPhoHad_2018',
# │   'SUEP-m1000-darkPho_2018',
# │   'SUEP-m1000-darkPhoHad_2018',
# │   'SUEP_mMed-125_mDark-2_temp-8_decay-darkPho_2018',
# │   'SUEP_mMed-125_mDark-2_temp-8_decay-darkPhoHad_2018',
# │   'SUEP_mMed-125_mDark-8_temp-8_decay-darkPho_2018',
# │   'SUEP_mMed-125_mDark-8_temp-8_decay-darkPhoHad_2018',
# │   'SUEP_mMed-125_mDark-4_temp-16_decay-darkPho_2018',
# │   'SUEP_mMed-125_mDark-4_temp-16_decay-darkPhoHad_2018',
# │   'SUEP_mMed-125_mDark-8_temp-16_decay-darkPho_2018',
# │   'SUEP_mMed-125_mDark-8_temp-16_decay-darkPhoHad_2018',
# │   'SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018',
# │   'SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018',
# │   'QCD_Pt-1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt_MuEnriched_2018',
# │   'QCD_Pt-120To170_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-15To20_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-170To300_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-20To30_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-300To470_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-30To50_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-470To600_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-50To80_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-600To800_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-800To1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'QCD_Pt-80To120_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'ST_t-channel_antitop_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'ST_t-channel_2018',
# │   'ST_t-channel_top_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT_2018',
# │   'WJetsToLNu_HT-1200To2500_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT-2500ToInf_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT-600To800_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT-70To100_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WWTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'bkg_2018',
# │   'WW_all_2018',
# │   'WWTo2L2Nu_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'WZTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WZ_all_2018',
# │   'WZTo1L3Nu_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WZTo2Q2L_mllmin4p0_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_normalized_2018',
# │   'WZTo3LNu_mllmin4p0_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_normalized_2018',
# │   'DYLowMass_NLO_2018',
# │   'ST_t-channel_antitop_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'ST_t-channel_top_5f_InclusiveDecays_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'ST_tW_2018',
# │   'WJetsToLNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WJetsToLNu_HT-1200To2500_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WJetsToLNu_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WJetsToLNu_HT-2500ToInf_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'WJetsToLNu_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WJetsToLNu_HT-600To800_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WJetsToLNu_HT-70To100_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WJets_inclusive_2018',
# │   'WWTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WWTo2L2Nu_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'WZTo1L1Nu2Q_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WZTo1L3Nu_4f_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WZTo2Q2L_mllmin4p0_TuneCP5_13TeV-amcatnloFXFX-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v1+NANOAODSIM_histograms_2018',
# │   'WZTo3LNu_mllmin4p0_TuneCP5_13TeV-powheg-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'DYJetsToLL_NLO_2018',
# │   'QCD_Pt-1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-120To170_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-15To20_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-170To300_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-20To30_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-300To470_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-30To50_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-470To600_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-50To80_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-600To800_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-800To1000_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'QCD_Pt-80To120_MuEnrichedPt5_TuneCP5_13TeV-pythia8+RunIISummer20UL18NanoAODv9-106X_upgrade2018_realistic_v16_L1v1-v2+NANOAODSIM_histograms_2018',
# │   'TTJets_2018',
# │   'ttZJets_2018',
# │   'WWZ_4F_2018',
# │   'ZZTo4L_2018',
# │   'ZZZ_2018',
# │   'DY_NLO_all_2018',
# │   'VVV_2018',
# │   'VV_2018',
# │   'ST_2018',
# │   'WJets_all_2018'
# ]

# %%
for key in plots['TTJets_2018'].keys():
    pprint(f"{key = }")
# Out:
# "key = 'ht'"
# "key = 'av_muon_pt'"
# "key = 'muon_pt'"
# "key = 'muon_eta'"

# %%
plots['QCD_Pt_MuEnriched_2018']['ht']
# Out:
# Hist(
#   Regular(30, 20, 2000, transform=log, name='ht'),
#   Regular(8, 0, 8, name='nMuon_ndf'),
#   Regular(8, 0, 8, name='nMuon'),
#   storage=Weight()) # Sum: WeightedSum(value=5370.41, variance=4.11436e+06)

# %% [markdown]
# ## Section with histograms for fitting

# %% [markdown]
# Will plot:
#   - lead_interiso_vs_av_muon_pt
#
# both as stacked & non-stacked plots.

# %% [markdown]
# ## Show post-cut plots

# %%
processes = [
    #'VVV_2018',
    'ttZJets_2018',
    'WJets_all_2018',
    'ST_2018',
    'VV_2018',
    'TTJets_2018',
    'DY_NLO_all_2018',
    'QCD_Pt_MuEnriched_2018',
]
signals = [
    'SUEP-m125-darkPho_2018',
    #'SUEP-m125-darkPhoHad_2018',
    'SUEP-m400-darkPho_2018',
    #'SUEP-m400-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-2_temp-8_decay-darkPho_2018',
    #'SUEP_mMed-125_mDark-2_temp-8_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-8_temp-8_decay-darkPho_2018',
    #'SUEP_mMed-125_mDark-8_temp-8_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-4_temp-16_decay-darkPho_2018',
    #'SUEP_mMed-125_mDark-4_temp-16_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-8_temp-16_decay-darkPho_2018',
    #'SUEP_mMed-125_mDark-8_temp-16_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018',
    #'SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018',
]
int_lumi = 59

plot_set = [
    [
        ('ht','ht'),
        {
            'xlog': True,
            'cut': (slice(None), slice(0, 10j, sum), slice(None, None, sum), slice(7j, None, sum)),
        }
    ],
    [
        ('lead_interiso_vs_av_muon_pt','av_Muon_pt'),
        {
            'xlog': True,
            'cut': (slice(1j, None, sum), slice(None), slice(None, None, sum), slice(7j, None, sum)),
            'slc': slice(None, 100j),
        }
    ],    [
        ('lead_interiso_vs_av_muon_pt','nMuon'),
        {
            'cut': (slice(1j, None, sum), slice(0, 10j, sum), slice(None, None, sum), slice(None)),
        }
    ],
]


for plot_i in plot_set:
    if plot_i[0][0] not in plots[processes[0]].keys():
        continue

    # Stack with ratio for processes
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(25, 12))
    plot_utils_extras.plot_stack(
        plots=plots, 
        bkg_list=processes, 
        sig_list=signals,
        label=plot_i[0],
        ylog=False,
        override_slice=False,
        fig=fig,
        ax=ax[0],
        int_lumi=int_lumi,
        #ylim= (0, 1e5),
        **plot_i[1]
    )
    plot_utils_extras.plot_stack(
        plots=plots, 
        bkg_list=processes, 
        sig_list=signals,
        label=plot_i[0],
        ylog=True,
        override_slice=False,
        fig=fig,
        ax=ax[1],
        int_lumi=int_lumi,
        #ylim= (1e-4, 1e8),
        **plot_i[1]
    )
    plt.tight_layout()
    plt.show()

    # Overlay for processes
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(22, 11))
    plot_utils_extras.plot_overlay(
        plots=plots, 
        bkg_list=processes, 
        label=plot_i[0], 
        override_slice=True,
        fig=fig,
        ax=ax[0],
        per_muon=True,
        int_lumi=int_lumi,
        **plot_i[1]
    )
    plot_utils_extras.plot_overlay(
        plots=plots, 
        bkg_list=processes, 
        label=plot_i[0], 
        override_slice=True,
        fig=fig,
        ax=ax[1],
        ylog=True,
        per_muon=True,
        int_lumi=int_lumi,
        **plot_i[1]
    )
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 2D plots per process

# %%
processes = [
    'VVV_2018',
    'ttZJets_2018',
    'WJets_all_2018',
    'ST_2018',
    'VV_2018',
    'TTJets_2018',
    'DY_NLO_all_2018',
    'QCD_Pt_MuEnriched_2018',
]
signal = [
    'SUEP-m125-darkPho_2018',
    'SUEP-m125-darkPhoHad_2018',
    'SUEP-m400-darkPho_2018',
    'SUEP-m400-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-2_temp-8_decay-darkPho_2018',
    'SUEP_mMed-125_mDark-2_temp-8_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-8_temp-8_decay-darkPho_2018',
    'SUEP_mMed-125_mDark-8_temp-8_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-4_temp-16_decay-darkPho_2018',
    'SUEP_mMed-125_mDark-4_temp-16_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-8_temp-16_decay-darkPho_2018',
    'SUEP_mMed-125_mDark-8_temp-16_decay-darkPhoHad_2018',
    'SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018',
    'SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018',
]

for p in processes:
    print(p)
    vals_tot = plots[p]['lead_interiso_vs_av_muon_pt'][::sum, ::sum, ::sum, ::sum]
    vals_cut = plots[p]['lead_interiso_vs_av_muon_pt'][1j:10j:sum, 3j:10j:sum, ::sum, ::sum]
    print(f"yield tot: {vals_tot.value:.3f} ± {np.sqrt(vals_tot.variance):.3f}")
    print(f"yield cut: {vals_cut.value:.3f} ± {np.sqrt(vals_cut.variance):.3f}")
    hep.hist2dplot(
        plots[p]['lead_interiso_vs_av_muon_pt'][::2j,::2j,::sum,::sum],
        norm=matplotlib.colors.LogNorm(),
    )
    plt.plot([1e-3, 10], [10, 10], c='r', lw=3, ls='--')
    plt.plot([1, 1], [3, 500], c='r', lw=3, ls='--')
    plt.xscale('log')
    plt.yscale('log')
    plt.show()

for s in signal:
    print(s)
    vals_tot = plots[s]['lead_interiso_vs_av_muon_pt'][::sum, ::sum, ::sum, ::sum]
    vals_cut = plots[s]['lead_interiso_vs_av_muon_pt'][1j:10j:sum, 3j:10j:sum, ::sum, ::sum]
    print(f"yield tot: {vals_tot.value:.3f} ± {np.sqrt(vals_tot.variance):.3f}")
    print(f"yield cut: {vals_cut.value:.3f} ± {np.sqrt(vals_cut.variance):.3f}")
    hep.hist2dplot(
        plots[s]['lead_interiso_vs_av_muon_pt'][::2j,::2j,::sum,::sum],
    )
    plt.plot([1e-3, 10], [10, 10], c='r', lw=3, ls='--')
    plt.plot([1, 1], [3, 500], c='r', lw=3, ls='--')
    plt.xscale('log')
    plt.yscale('log')
    plt.show()
# Out:
# VVV_2018
# yield tot: 63.603 ± 0.256
# yield cut: 0.035 ± 0.006
# ttZJets_2018
# yield tot: 504.104 ± 0.673
# yield cut: 1.225 ± 0.033
# WJets_all_2018
# yield tot: 2516.419 ± 750.671
# yield cut: 1.417 ± 0.147
# ST_2018
# yield tot: 3210.913 ± 15.706
# yield cut: 1.203 ± 0.225
# VV_2018
# yield tot: 5357.059 ± 6.997
# yield cut: 30.984 ± 0.610
# TTJets_2018
# yield tot: 151821.460 ± 426.201
# yield cut: 676.777 ± 28.710
# DY_NLO_all_2018
# yield tot: 463397.579 ± 2434.266
# yield cut: 2757.839 ± 253.305
# QCD_Pt_MuEnriched_2018
# yield tot: 281.412 ± 0.603
# yield cut: 21.584 ± 0.168
# SUEP-m125-darkPho_2018
# yield tot: 457572.877 ± 10952.836
# yield cut: 315169.670 ± 8854.345
# SUEP-m125-darkPhoHad_2018
# yield tot: 59717.517 ± 3895.545
# yield cut: 33541.542 ± 2919.420
# SUEP-m400-darkPho_2018
# yield tot: 118830.135 ± 1438.281
# yield cut: 99018.845 ± 1312.920
# SUEP-m400-darkPhoHad_2018
# yield tot: 29505.634 ± 713.105
# yield cut: 20353.682 ± 592.268
# SUEP_mMed-125_mDark-2_temp-8_decay-darkPho_2018
# yield tot: 1034884.256 ± 16134.653
# yield cut: 346386.879 ± 9334.573
# SUEP_mMed-125_mDark-2_temp-8_decay-darkPhoHad_2018
# yield tot: 180111.115 ± 6731.068
# yield cut: 55341.404 ± 3731.117
# SUEP_mMed-125_mDark-8_temp-8_decay-darkPho_2018
# yield tot: 1089868.457 ± 16391.316
# yield cut: 317025.749 ± 8840.443
# SUEP_mMed-125_mDark-8_temp-8_decay-darkPhoHad_2018
# yield tot: 173848.523 ± 6681.541
# yield cut: 35437.365 ± 3016.629
# SUEP_mMed-125_mDark-4_temp-16_decay-darkPho_2018
# yield tot: 688203.900 ± 13293.818
# yield cut: 62914.163 ± 4019.438
# SUEP_mMed-125_mDark-4_temp-16_decay-darkPhoHad_2018
# yield tot: 101626.942 ± 5056.129
# yield cut: 7798.107 ± 1400.581
# SUEP_mMed-125_mDark-8_temp-16_decay-darkPho_2018
# yield tot: 724154.850 ± 13636.625
# yield cut: 76524.165 ± 4432.926
# SUEP_mMed-125_mDark-8_temp-16_decay-darkPhoHad_2018
# yield tot: 97622.237 ± 4905.702
# yield cut: 8381.707 ± 1437.451
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018
# yield tot: 457671.224 ± 11074.131
# yield cut: 8842.594 ± 1539.298
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018
# yield tot: 59658.034 ± 3834.964
# yield cut: 1232.604 ± 551.237

# %% [markdown]
# ## 2D plots for signal per nMuon

# %%
signal = 'SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018'
# signal = 'SUEP-m400-darkPho_2018'
for n in range(3, 10):
    print(signal, "nMuon =", n)
    vals_tot = plots[signal]['lead_interiso_vs_av_muon_pt'][::sum, ::sum, ::sum, n*1j]
    vals_cut = plots[signal]['lead_interiso_vs_av_muon_pt'][1j:10j:sum, 3j:10j:sum, ::sum, n*1j]
    print(f"yield tot: {vals_tot.value:.3f} ± {np.sqrt(vals_tot.variance):.3f}")
    print(f"yield cut: {vals_cut.value:.3f} ± {np.sqrt(vals_cut.variance):.3f}")
    hep.hist2dplot(
        plots[signal]['lead_interiso_vs_av_muon_pt'][::2j, ::2j, ::sum, n*1j],
    )
    plt.plot([1e-3, 10], [10, 10], c='r', lw=3, ls='--')
    plt.plot([1, 1], [3, 500], c='r', lw=3, ls='--')
    plt.xscale('log')
    plt.yscale('log')
    plt.show()
# Out:
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018 nMuon = 3
# yield tot: 6656.062 ± 1280.960
# yield cut: 0.000 ± 0.000
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018 nMuon = 4
# yield tot: 36238.558 ± 2988.906
# yield cut: 493.042 ± 348.633
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018 nMuon = 5
# yield tot: 11339.957 ± 1671.985
# yield cut: 739.562 ± 426.987
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018 nMuon = 6
# yield tot: 5423.458 ± 1156.285
# yield cut: 0.000 ± 0.000
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018 nMuon = 7
# yield tot: 0.000 ± 0.000
# yield cut: 0.000 ± 0.000
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018 nMuon = 8
# yield tot: 0.000 ± 0.000
# yield cut: 0.000 ± 0.000
# SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018 nMuon = 9
# yield tot: 0.000 ± 0.000
# yield cut: 0.000 ± 0.000

# %% [markdown]
# ## Calculate total bkg

# %%
processes = [
    'VVV_2018',
    'ttZJets_2018',
    'WJets_all_2018',
    'ST_2018',
    'VV_2018',
    'TTJets_2018',
    'DY_NLO_all_2018',
    'QCD_Pt_MuEnriched_2018',
]

h_tot = None
for p in processes:
    if h_tot is None:
        h_tot = plots[p]['lead_interiso_vs_av_muon_pt'].copy()
    else:
        h_tot += plots[p]['lead_interiso_vs_av_muon_pt'].copy()

# %% [markdown]
# ### Other vars distributions per nMuon

# %%
for n in range(3, 10):
    print('nMuon =', n)
    vals_tot = h_tot[::sum, ::sum, ::sum, n*1j]
    vals_cut = h_tot[1j:10j:sum, 3j:10j:sum, ::sum, n*1j]
    print(f"yield tot: {vals_tot.value:.3f} ± {np.sqrt(vals_tot.variance):.3f}")
    print(f"yield cut: {vals_cut.value:.3f} ± {np.sqrt(vals_cut.variance):.3f}")
    fig, ax = plt.subplots(ncols=3, figsize=(23,7))
    hep.histplot(h_tot[1e-2j:10j, ::sum, ::sum, n*1j], ax=ax[0])
    ax[0].plot([1, 1], plt.gca().get_ylim(), c='r', lw=3, ls='--')
    ax[0].set_xscale('log')
    hep.histplot(h_tot[::sum, :, ::sum, n*1j], ax=ax[1])
    ax[1].plot([10, 10], plt.gca().get_ylim(), c='r', lw=3, ls='--')
    ax[1].set_xscale('log')
    hep.hist2dplot(
        h_tot[1::4j, ::4j, ::sum, n*1j],
        ax=ax[2]
    )
    ax[2].plot([1e-3, 10], [10, 10], c='r', lw=3, ls='--')
    ax[2].plot([1, 1], [3, 500], c='r', lw=3, ls='--')
    ax[2].set_xscale('log')
    ax[2].set_yscale('log')
    plt.show()
# Out:
# nMuon = 3
# yield tot: 599353.834 ± 2550.598
# yield cut: 3107.745 ± 245.949
# nMuon = 4
# yield tot: 26917.255 ± 401.792
# yield cut: 372.989 ± 66.986
# nMuon = 5
# yield tot: 860.960 ± 63.714
# yield cut: 9.894 ± 3.029
# nMuon = 6
# yield tot: 20.043 ± 7.468
# yield cut: 0.435 ± 0.913
# nMuon = 7
# yield tot: 0.457 ± 0.707
# yield cut: 0.002 ± 0.002
# nMuon = 8
# yield tot: 0.001 ± 0.001
# yield cut: 0.000 ± 0.000
# nMuon = 9
# yield tot: 0.000 ± 0.000
# yield cut: 0.000 ± 0.000

# %% [markdown]
# ### nMuon distribution

# %%
hep.histplot(h_tot[::sum, ::sum, ::sum, :])
plt.yscale('log')
plt.show()

# %%
from iminuit import Minuit
from iminuit.cost import LeastSquares
from jacobi import propagate

# %%
def muon_func(x, a, b, c):
    return a*np.exp(b*x)+c

# %%
def muon_func(x, a, b, c, d):
    return a*b**(x**c)+d

# %%
h0 = plots['QCD_Pt_MuEnriched_2018']['lead_interiso_vs_av_muon_pt'][::sum, ::sum, ::sum, :]
data_x = h0.axes[0].edges[3:7]
data_y = h0.values()[3:7]
data_yerr = np.sqrt(h0.variances())[3:7]
least_squares = LeastSquares(data_x, data_y, data_yerr, muon_func)
m = Minuit(least_squares, a=1e5, b=0.5, c=1, d=0)
m.fixto("d", 0)
m.migrad(ncall=10000)
m.hesse()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 5.009 (χ²/ndof = 5.0)      │              Nfcn = 591              │
# │ EDM = 0.000116 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │  2.33e3   │  0.13e3   │            │            │         │         │       │
# │ 1 │ b    │   0.807   │   0.011   │            │            │         │         │       │
# │ 2 │ c    │   2.14    │   0.04    │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────┐
# │   │        a        b        c        d │
# ├───┼─────────────────────────────────────┤
# │ a │ 1.79e+04 -1.51816  -4.9175        0 │
# │ b │ -1.51816  0.00013  0.42e-3        0 │
# │ c │  -4.9175  0.42e-3  0.00137   0.0000 │
# │ d │        0        0   0.0000        0 │
# └───┴─────────────────────────────────────┘

# %%
x = np.arange(3,10)
y, ycov = propagate(lambda p: muon_func(x, *p), m.values, m.covariance)
yerr_prop = np.diag(ycov) ** 0.5
x_hatch = np.vstack(
    (np.arange(3,10), np.arange(4,11))
).reshape((-1,), order="F")
y_hatch = np.vstack(
    (y, y)
).reshape((-1,), order="F")
y_hatch_unc = np.vstack(
    (yerr_prop, yerr_prop)
).reshape((-1,), order="F")

# %%
hep.histplot(h0)
#plt.plot(data_x, muon_func(data_x, *(m.values)))
hep.histplot(y, bins=np.arange(3,11))
#plt.plot(x, y, lw=3, label="fit")
plt.fill_between(
    x=x_hatch,
    y1=y_hatch - y_hatch_unc,
    y2=y_hatch + y_hatch_unc,
    label="Stat. Unc.",
    step="pre",
    facecolor="C1", 
    alpha=0.3,
    #facecolor="none",
    #edgecolor=(0, 0, 0, 0.5),
    linewidth=0,
    #hatch="///",
)
#plt.fill_between(x, y - yerr_prop, y + yerr_prop, facecolor="C1", alpha=0.5)
plt.yscale('log')
plt.show()

# %%
np.arange(3,10)
# Out:
# array([3, 4, 5, 6, 7, 8, 9])

# %%
processes = [
    'VVV_2018',
    'ttZJets_2018',
    'WJets_all_2018',
    'ST_2018',
    'VV_2018',
    'TTJets_2018',
    'DY_NLO_all_2018',
    'QCD_Pt_MuEnriched_2018',
]

for p in processes:
    print(p)
    h0 = plots[p]['lead_interiso_vs_av_muon_pt'][::sum, ::sum, ::sum, :]
    data_x = h0.axes[0].edges[3:7]
    data_y = h0.values()[3:7]
    print(f"{data_x=}")
    print(f"{data_y=}")
    data_yerr = np.sqrt(h0.variances())[3:7]
    least_squares = LeastSquares(data_x, data_y, data_yerr, muon_func)
    m = Minuit(least_squares, a=1e5, b=0.5, c=1, d=0)
    m.fixto("d", 0)
    m.migrad(ncall=10000)
    m.hesse()
    print(m)
    x = np.arange(3,10)
    y, ycov = propagate(lambda p: muon_func(x, *p), m.values, m.covariance)
    yerr_prop = np.diag(ycov) ** 0.5
    x_hatch = np.vstack(
        (np.arange(3,10), np.arange(4,11))
    ).reshape((-1,), order="F")
    y_hatch = np.vstack(
        (y, y)
    ).reshape((-1,), order="F")
    y_hatch_unc = np.vstack(
        (yerr_prop, yerr_prop)
    ).reshape((-1,), order="F")
    vals_tot = plots[p]['lead_interiso_vs_av_muon_pt'][::sum, ::sum, ::sum, 6j::sum]
    vals_cut = plots[p]['lead_interiso_vs_av_muon_pt'][1j:10j:sum, 3j:10j:sum, ::sum, 6j::sum]
    print(f"yield tot: {vals_tot.value:.3f} ± {np.sqrt(vals_tot.variance):.3f}")
    print(f"yield cut: {vals_cut.value:.3f} ± {np.sqrt(vals_cut.variance):.3f}")
    hep.histplot(plots[p]['lead_interiso_vs_av_muon_pt'][::sum, ::sum, ::sum, :])
    #hep.histplot(plots[p]['lead_interiso_vs_av_muon_pt'][1j:10j:sum, 3j:10j:sum, ::sum, :])
    hep.histplot(y, bins=np.arange(3,11))
    plt.fill_between(
        x=x_hatch,
        y1=y_hatch - y_hatch_unc,
        y2=y_hatch + y_hatch_unc,
        label="Stat. Unc.",
        step="pre",
        facecolor="C1", 
        alpha=0.3,
        linewidth=0,
    )
    plt.yscale('log')
    plt.show()
# Out:
# VVV_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([5.66802382e+01, 6.66056990e+00, 2.35559694e-01, 2.66957446e-02])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 5.555e+04 (χ²/ndof = 55547.8)│              Nfcn = 182              │
# │ EDM = 1.59e+05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │     Covariance FORCED pos. def.      │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │    50     │     9     │            │            │         │         │       │
# │ 1 │ b    │   0.453   │   0.004   │            │            │         │         │       │
# │ 2 │ c    │   1.081   │   0.011   │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────────────┐
# │   │          a          b          c          d │
# ├───┼─────────────────────────────────────────────┤
# │ a │       74.8 -29.218e-3   95.96e-3          0 │
# │ b │ -29.218e-3    1.3e-05  -0.035e-3          0 │
# │ c │   95.96e-3  -0.035e-3   0.000127          0 │
# │ d │          0          0          0          0 │
# └───┴─────────────────────────────────────────────┘
# yield tot: 0.027 ± 0.003
# yield cut: 0.000 ± 0.000
# ttZJets_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([418.36801532,  77.88028668,   7.37923045,   0.44692634])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 20.47 (χ²/ndof = 20.5)     │              Nfcn = 523              │
# │ EDM = 2.78e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │  2.55e3   │  0.06e3   │            │            │         │         │       │
# │ 1 │ b    │   0.864   │   0.005   │            │            │         │         │       │
# │ 2 │ c    │   2.287   │   0.021   │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────────────────┐
# │   │           a           b           c           d │
# ├───┼─────────────────────────────────────────────────┤
# │ a │    4.22e+03 -298.808e-3     -1.3305         0e3 │
# │ b │ -298.808e-3    2.14e-05    0.096e-3           0 │
# │ c │     -1.3305    0.096e-3     0.00043           0 │
# │ d │         0e3           0           0           0 │
# └───┴─────────────────────────────────────────────────┘
# yield tot: 0.477 ± 0.021
# yield cut: 0.002 ± 0.001
# WJets_all_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([2.50182004e+03, 1.36476375e+01, 9.34334070e-01, 1.68163024e-02])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 954.8 (χ²/ndof = 954.8)    │              Nfcn = 182              │
# │ EDM = 994 (Goal: 0.0002)         │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │     Covariance FORCED pos. def.      │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │    21     │    35     │            │            │         │         │       │
# │ 1 │ b    │   0.454   │   0.034   │            │            │         │         │       │
# │ 2 │ c    │   1.08    │   0.11    │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────┐
# │   │        a        b        c        d │
# ├───┼─────────────────────────────────────┤
# │ a │ 1.24e+03  -1.0912    3.674        0 │
# │ b │  -1.0912  0.00117  -0.0030   0.0000 │
# │ c │    3.674  -0.0030   0.0114    0.000 │
# │ d │        0   0.0000    0.000        0 │
# └───┴─────────────────────────────────────┘
# yield tot: 0.017 ± 0.011
# yield cut: 0.000 ± 0.000
# ST_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([3.01652830e+03, 1.88241124e+02, 6.04402248e+00, 9.93513890e-02])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 0.000532 (χ²/ndof = 0.0)   │              Nfcn = 296              │
# │ EDM = 8.68e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │  0.15e6   │  0.07e6   │            │            │         │         │       │
# │ 1 │ b    │   0.60    │   0.08    │            │            │         │         │       │
# │ 2 │ c    │   1.86    │   0.15    │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────────────────┐
# │   │           a           b           c           d │
# ├───┼─────────────────────────────────────────────────┤
# │ a │    4.33e+09 -5.540242e3 -9.933373e3         0e9 │
# │ b │ -5.540242e3     0.00711       0.013       0.000 │
# │ c │ -9.933373e3       0.013      0.0229       0.000 │
# │ d │         0e9       0.000       0.000           0 │
# └───┴─────────────────────────────────────────────────┘
# yield tot: 0.099 ± 0.120
# yield cut: 0.000 ± 0.000
# VV_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([3.88029999e+03, 1.46004235e+03, 1.62457485e+01, 4.65863413e-01])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 203.2 (χ²/ndof = 203.2)    │             Nfcn = 1178              │
# │ EDM = 2.14 (Goal: 0.0002)        │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │     Covariance FORCED pos. def.      │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │  4.484e3  │  0.009e3  │            │            │         │         │       │
# │ 1 │ b    │999.9481e-3│ 0.0005e-3 │            │            │         │         │       │
# │ 2 │ c    │   7.200   │   0.007   │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────────────────────────────┐
# │   │              a              b              c              d │
# ├───┼─────────────────────────────────────────────────────────────┤
# │ a │           85.5 -3.65095615e-6      -38.99e-3              0 │
# │ b │ -3.65095615e-6       2.94e-13     3.51642e-9              0 │
# │ c │      -38.99e-3     3.51642e-9       4.29e-05              0 │
# │ d │              0              0              0              0 │
# └───┴─────────────────────────────────────────────────────────────┘
# yield tot: 0.471 ± 0.033
# yield cut: 0.001 ± 0.001
# TTJets_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([1.39048468e+05, 1.21905630e+04, 5.65682639e+02, 1.63374047e+01])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 0.1821 (χ²/ndof = 0.2)     │              Nfcn = 270              │
# │ EDM = 2.9e-05 (Goal: 0.0002)     │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │   3.8e6   │   0.6e6   │            │            │         │         │       │
# │ 1 │ b    │   0.666   │   0.034   │            │            │         │         │       │
# │ 2 │ c    │   1.91    │   0.07    │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────────────────────────┐
# │   │             a             b             c             d │
# ├───┼─────────────────────────────────────────────────────────┤
# │ a │      3.98e+11 -21.3571562e3  -43.510156e3             0 │
# │ b │ -21.3571562e3       0.00115        0.0023        0.0000 │
# │ c │  -43.510156e3        0.0023       0.00479         0.000 │
# │ d │             0        0.0000         0.000             0 │
# └───┴─────────────────────────────────────────────────────────┘
# yield tot: 16.746 ± 4.952
# yield cut: 0.408 ± 0.913
# DY_NLO_all_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([4.50188458e+05, 1.29447996e+04, 2.61802010e+02, 2.51915630e+00])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 0.0509 (χ²/ndof = 0.1)     │             Nfcn = 1753              │
# │ EDM = 0.000192 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │  0.57e9   │  0.33e9   │            │            │         │         │       │
# │ 1 │ b    │   0.22    │   0.06    │            │            │         │         │       │
# │ 2 │ c    │   1.40    │   0.09    │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────────────────────────────────────┐
# │   │                a                b                c                d │
# ├───┼─────────────────────────────────────────────────────────────────────┤
# │ a │         1.07e+17 -19.4540053215e6  -29.705409804e6                0 │
# │ b │ -19.4540053215e6          0.00353           0.0054           0.0000 │
# │ c │  -29.705409804e6           0.0054           0.0083            0.000 │
# │ d │                0           0.0000            0.000                0 │
# └───┴─────────────────────────────────────────────────────────────────────┘
# yield tot: 2.519 ± 5.633
# yield cut: 0.000 ± 0.000
# QCD_Pt_MuEnriched_2018
# data_x=array([3., 4., 5., 6.])
# data_y=array([2.43210694e+02, 3.54202586e+01, 2.63636436e+00, 1.30825121e-01])
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 5.009 (χ²/ndof = 5.0)      │              Nfcn = 591              │
# │ EDM = 0.000116 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │  2.33e3   │  0.13e3   │            │            │         │         │       │
# │ 1 │ b    │   0.807   │   0.011   │            │            │         │         │       │
# │ 2 │ c    │   2.14    │   0.04    │            │            │         │         │       │
# │ 3 │ d    │    0.0    │    0.1    │            │            │         │         │  yes  │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────────────────────────┐
# │   │        a        b        c        d │
# ├───┼─────────────────────────────────────┤
# │ a │ 1.79e+04 -1.51816  -4.9175        0 │
# │ b │ -1.51816  0.00013  0.42e-3        0 │
# │ c │  -4.9175  0.42e-3  0.00137   0.0000 │
# │ d │        0        0   0.0000        0 │
# └───┴─────────────────────────────────────┘
# yield tot: 0.145 ± 0.014
# yield cut: 0.026 ± 0.006

# %%
print(*(m.values))
# Out:
# 2131.5334042696313 1.1576795499589272 -1.3093930666116385 2.2089998224250524 0.037529279039633205

# %% [markdown]
# ## Significance scans

# %%
def enumerated_product(*args):
    for e in zip(itertools.product(*(range(len(x)) for x in args)), itertools.product(*args)):
        yield e

# %%
def asimov_sig(S, B):
    B[np.isclose(B, 0)] = 1e-8
    B[B < 0] = 1e-8
    return np.sqrt(2*((S + B)*np.log(1 + S/B) - S))

def S_12(S, B):
    B[B < 0] = 0
    return 2*(np.sqrt(S + B) - np.sqrt(B))

def S_over_SB(S, B):
    B[B < 0] = 0
    return S/np.sqrt(S + B)

def S_over_BdB(S, B, deltaB2):
    B[B < 0] = 0
    return S/np.sqrt(B + deltaB2)

def punzi(S_eff, B, a=2, b=2):
    B[B < 0] = 0
    return S_eff/(b**2 + 2*a*np.sqrt(B) + b*np.sqrt(b**2 + 4*a*np.sqrt(B) + 4*B))
    
def punzi_imp(S_eff, B, a=2, b=2):
    B[B < 0] = 0
    return S_eff/(a**2/4 + 18*b**2/13 + 2*a*np.sqrt(B) + b*np.sqrt(b**2 + 4*a*np.sqrt(B) + 4*B))

# %%
def muon_scaling(x, A, B):
    return A*np.exp(-B*x)

# %%
[p.shape for p in plots['QCD_Pt_MuEnriched_2018']['lead_interiso_vs_av_muon_pt'][0.5j:2j,3j:20j,::sum,::sum].axes.edges]
# Out:
# [(9, 1), (1, 19)]

# %%
np.set_printoptions(precision=4)

# %%
m.valid & m.accurate
# Out:
# True

# %%
m.limits(B, 2, None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10105/2525447815.py in <module>
# ----> 1 m.limits(B, 2, None)
#
# TypeError: 'LimitView' object is not callable

# %%
processes = [
    'VVV_2018',
    'ttZJets_2018',
    'WJets_all_2018',
    'ST_2018',
    'VV_2018',
    'TTJets_2018',
    'DY_NLO_all_2018',
    'QCD_Pt_MuEnriched_2018',
]

signals = [
    'SUEP-m125-darkPho_2018',
    'SUEP-m400-darkPho_2018',
    'SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018',
    'SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018',
]

#nMuon_cut = np.array([5, 6, 7])
nMuon_cut = np.array([6])
lead_interiso_cut = np.linspace(0.5, 2, 21)
av_muon_pt_cut = np.linspace(3.4, 20, 21)

# Don't scan nMuon for now. nMuon≥6 is clearly superior.
# for nMu in nMuon_cut:
nMu = nMuon_cut[0]
# print(f"Looking at nMuon >= {nMu}")
B = np.zeros((len(lead_interiso_cut), len(av_muon_pt_cut)))
deltaB2 = np.zeros((len(lead_interiso_cut), len(av_muon_pt_cut)))
S = {}
S_tot = {}
for signal in signals:
    S_tot[signal] = plots[signal]['lead_interiso_vs_av_muon_pt'].sum().value
    S[signal] = np.zeros((len(lead_interiso_cut), len(av_muon_pt_cut)))
for (l_iso_i, av_pt_i), (l_iso, av_pt) in enumerated_product(lead_interiso_cut, av_muon_pt_cut):
    cut = (
        slice((l_iso*1j), None, sum), 
        slice(None, (av_pt*1j), sum), 
        slice(None, None, sum), 
        slice(None),
    )
    adj_proc = []
    adj_values = []
    for p in processes:
        h_temp = plots[p]['lead_interiso_vs_av_muon_pt'][cut].copy()
        # You can inject here whatever extrapolation you want if h_temp[(nMu*1j)::sum] gives ≤0 
        if not (h_temp[6j::sum].value > 0) and (h_temp[5j].value > 0):
            if h_temp[6j::sum].value < 0:
                print(l_iso, av_pt, p, h_temp[6j::sum].value)
            adj_proc.append(p.replace('_2018',''))
            adj_values.append(h_temp[5j].value)
        if h_temp[(nMu*1j)::sum].value >= 0:
            B[l_iso_i, av_pt_i] += h_temp[(nMu*1j)::sum].value
            deltaB2[l_iso_i, av_pt_i] += h_temp[(nMu*1j)::sum].variance
    if len(adj_proc):
        adj_values = np.array(adj_values)
        vals_to_keep = []
        procs_to_keep = []
        extrapolations = []
        for p, v in zip([adj_proc[i] for i in np.argsort(adj_values)[::-1]], np.sort(adj_values)[::-1]):
            if v >= 0.1*max(adj_values):
                vals_to_keep.append(v)
                procs_to_keep.append(p)
        for p, v in zip(procs_to_keep, vals_to_keep):
            h_temp = plots[p + '_2018']['lead_interiso_vs_av_muon_pt'][cut].copy()
            data_x = np.array([3, 4, 5])
            data_y = h_temp[3j:6j].values()
            data_yerr = np.sqrt(h_temp[3j:6j].variances())
            least_squares = LeastSquares(data_x, data_y, data_yerr, muon_scaling)
            m = Minuit(least_squares, A=1e5, B=1)
            m.limits = [(0, None), (1, None)]
            m.migrad()
            extrapolations.append(muon_scaling(6, *m.values))
            if not m.valid or not m.accurate:
                print("Warning: fit not accurate or valid!!!")
                continue
            if muon_scaling(6, *m.values) <= 0.25 * h_temp[5j].value:
                B[l_iso_i, av_pt_i] += muon_scaling(6, *m.values)
            else:
                print("Warning!!! Extrapolation is off!!!")
        print(f"{procs_to_keep} with {np.array(vals_to_keep)} for ({l_iso:.3f}, {av_pt:.3f}) cuts")
        print(f"\tm.values: {np.array([m.values['A'], m.values['B']])}, extrapolation: {np.array(extrapolations)}")
    for signal in signals:
        h_temp = plots[signal]['lead_interiso_vs_av_muon_pt'][cut].copy()
        S[signal][l_iso_i, av_pt_i] = h_temp[(nMu*1j)::sum].value
# Out:
# ['QCD_Pt_MuEnriched', 'VV'] with [0.0019 0.0015] for (0.500, 4.230) cuts
# 	m.values: [29.8835  2.2158], extrapolation: [6.7642e-05 5.0286e-05]
# ['TTJets'] with [1.2253] for (0.500, 5.060) cuts
# 	m.values: [9.6169e+04 2.5168e+00], extrapolation: [0.0266]
# ['TTJets'] with [2.859] for (0.500, 5.890) cuts
# 	m.values: [3.7282e+04 1.8913e+00], extrapolation: [0.4396]
# ['TTJets'] with [3.2675] for (0.500, 6.720) cuts
# 	m.values: [1.2012e+05 2.0625e+00], extrapolation: [0.5073]
# ['DY_NLO_all', 'TTJets'] with [15.0832  8.1687] for (0.500, 7.550) cuts
# 	m.values: [4.4421e+05 2.1392e+00], extrapolation: [0.3412 1.1843]
# ['DY_NLO_all', 'TTJets'] with [15.0832 11.8446] for (0.500, 8.380) cuts
# 	m.values: [7.7669e+05 2.1748e+00], extrapolation: [0.3229 1.6721]
# ['DY_NLO_all', 'TTJets'] with [15.0832 11.8446] for (0.500, 9.210) cuts
# 	m.values: [7.7669e+05 2.1748e+00], extrapolation: [0.3229 1.6721]
# ['DY_NLO_all'] with [15.0832] for (0.500, 10.040) cuts
# 	m.values: [3.9632e+08 3.3947e+00], extrapolation: [0.5653]
# ['DY_NLO_all'] with [42.7305] for (0.500, 10.870) cuts
# 	m.values: [4.8136e+08 3.3753e+00], extrapolation: [0.7711]
# ['DY_NLO_all'] with [42.7305] for (0.500, 11.700) cuts
# 	m.values: [5.0928e+08 3.3304e+00], extrapolation: [1.0686]
# ['DY_NLO_all'] with [42.7305] for (0.500, 12.530) cuts
# 	m.values: [5.0928e+08 3.3304e+00], extrapolation: [1.0686]
# ['DY_NLO_all'] with [42.7305] for (0.500, 13.360) cuts
# 	m.values: [7.0253e+08 3.3793e+00], extrapolation: [1.0988]
# ['DY_NLO_all'] with [55.2946] for (0.500, 14.190) cuts
# 	m.values: [9.9716e+08 3.4434e+00], extrapolation: [1.0616]
# ['DY_NLO_all'] with [55.2946] for (0.500, 15.020) cuts
# 	m.values: [9.9716e+08 3.4434e+00], extrapolation: [1.0616]
# 0.5 15.850000000000001 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [70.3778] for (0.500, 15.850) cuts
# 	m.values: [1.1688e+09 3.4578e+00], extrapolation: [1.1418]
# 0.5 16.68 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [70.3778] for (0.500, 16.680) cuts
# 	m.values: [1.1688e+09 3.4578e+00], extrapolation: [1.1418]
# 0.5 17.51 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [70.3778] for (0.500, 17.510) cuts
# 	m.values: [1.4835e+09 3.5032e+00], extrapolation: [1.1036]
# 0.5 18.34 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [70.3778] for (0.500, 18.340) cuts
# 	m.values: [1.4835e+09 3.5032e+00], extrapolation: [1.1036]
# ['DY_NLO_all'] with [85.4611] for (0.500, 19.170) cuts
# 	m.values: [1.5327e+09 3.4903e+00], extrapolation: [1.2318]
# ['DY_NLO_all'] with [85.4611] for (0.500, 20.000) cuts
# 	m.values: [1.5327e+09 3.4903e+00], extrapolation: [1.2318]
# ['QCD_Pt_MuEnriched', 'VV'] with [0.0019 0.0015] for (0.575, 4.230) cuts
# 	m.values: [23.2935  2.1522], extrapolation: [5.7195e-05 5.7432e-05]
# ['TTJets'] with [1.2253] for (0.575, 5.060) cuts
# 	m.values: [3.9428e+04 2.2706e+00], extrapolation: [0.0478]
# ['TTJets'] with [2.859] for (0.575, 5.890) cuts
# 	m.values: [2.8529e+04 1.8394e+00], extrapolation: [0.4595]
# ['TTJets'] with [3.6759] for (0.575, 6.720) cuts
# 	m.values: [7.5961e+04 1.9555e+00], extrapolation: [0.6094]
# ['TTJets'] with [8.5771] for (0.575, 7.550) cuts
# 	m.values: [3.1084e+05 2.0730e+00], extrapolation: [1.2328]
# ['TTJets'] with [12.2531] for (0.575, 8.380) cuts
# 	m.values: [5.7431e+05 2.1278e+00], extrapolation: [1.6391]
# ['TTJets'] with [12.2531] for (0.575, 9.210) cuts
# 	m.values: [5.7431e+05 2.1278e+00], extrapolation: [1.6391]
# ['WJets_all'] with [0.0564] for (0.575, 10.040) cuts
# 	m.values: [338.2672   1.709 ], extrapolation: [0.0119]
# ['DY_NLO_all'] with [12.5641] for (0.575, 10.870) cuts
# 	m.values: [4.8183e+08 3.4425e+00], extrapolation: [0.5158]
# ['DY_NLO_all'] with [12.5641] for (0.575, 11.700) cuts
# 	m.values: [5.1816e+08 3.4031e+00], extrapolation: [0.7026]
# ['DY_NLO_all'] with [12.5641] for (0.575, 12.530) cuts
# 	m.values: [5.1816e+08 3.4031e+00], extrapolation: [0.7026]
# ['DY_NLO_all'] with [12.5641] for (0.575, 13.360) cuts
# 	m.values: [7.0177e+08 3.4500e+00], extrapolation: [0.7184]
# ['DY_NLO_all'] with [25.1281] for (0.575, 14.190) cuts
# 	m.values: [8.8797e+08 3.4741e+00], extrapolation: [0.7865]
# ['DY_NLO_all'] with [25.1281] for (0.575, 15.020) cuts
# 	m.values: [8.8797e+08 3.4741e+00], extrapolation: [0.7865]
# 0.575 15.850000000000001 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [42.7305] for (0.575, 15.850) cuts
# 	m.values: [9.4739e+08 3.4591e+00], extrapolation: [0.9183]
# 0.575 16.68 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [42.7305] for (0.575, 16.680) cuts
# 	m.values: [9.4739e+08 3.4591e+00], extrapolation: [0.9183]
# 0.575 17.51 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [42.7305] for (0.575, 17.510) cuts
# 	m.values: [1.2164e+09 3.5076e+00], extrapolation: [0.8813]
# 0.575 18.34 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [42.7305] for (0.575, 18.340) cuts
# 	m.values: [1.2164e+09 3.5076e+00], extrapolation: [0.8813]
# ['DY_NLO_all'] with [57.8138] for (0.575, 19.170) cuts
# 	m.values: [1.1972e+09 3.4780e+00], extrapolation: [1.0356]
# ['DY_NLO_all'] with [57.8138] for (0.575, 20.000) cuts
# 	m.values: [1.1972e+09 3.4780e+00], extrapolation: [1.0356]
# ['QCD_Pt_MuEnriched', 'VV'] with [0.0019 0.0007] for (0.650, 4.230) cuts
# 	m.values: [79.0055  2.6948], extrapolation: [5.0956e-05 7.5092e-06]
# ['TTJets'] with [1.2253] for (0.650, 5.060) cuts
# 	m.values: [6.4510e+04 2.4574e+00], extrapolation: [0.0255]
# ['TTJets'] with [2.859] for (0.650, 5.890) cuts
# 	m.values: [2.3228e+04 1.8178e+00], extrapolation: [0.4257]
# ['TTJets'] with [3.2675] for (0.650, 6.720) cuts
# 	m.values: [7.0389e+04 1.9736e+00], extrapolation: [0.5068]
# ['TTJets'] with [7.7603] for (0.650, 7.550) cuts
# 	m.values: [2.0688e+05 2.0109e+00], extrapolation: [1.1906]
# ['TTJets'] with [11.4362] for (0.650, 8.380) cuts
# 	m.values: [3.9850e+05 2.0747e+00], extrapolation: [1.5639]
# ['TTJets'] with [11.4362] for (0.650, 9.210) cuts
# 	m.values: [3.9850e+05 2.0747e+00], extrapolation: [1.5639]
# ['WJets_all'] with [0.0564] for (0.650, 10.040) cuts
# 	m.values: [224.7188   1.6173], extrapolation: [0.0137]
# ['DY_NLO_all'] with [12.5641] for (0.650, 10.870) cuts
# 	m.values: [2.2657e+08 3.2953e+00], extrapolation: [0.5866]
# ['DY_NLO_all'] with [12.5641] for (0.650, 11.700) cuts
# 	m.values: [2.2680e+08 3.2274e+00], extrapolation: [0.8827]
# ['DY_NLO_all'] with [12.5641] for (0.650, 12.530) cuts
# 	m.values: [2.2680e+08 3.2274e+00], extrapolation: [0.8827]
# ['DY_NLO_all'] with [12.5641] for (0.650, 13.360) cuts
# 	m.values: [3.4914e+08 3.3117e+00], extrapolation: [0.8196]
# ['DY_NLO_all'] with [12.5641] for (0.650, 14.190) cuts
# 	m.values: [5.3593e+08 3.3984e+00], extrapolation: [0.7475]
# ['DY_NLO_all'] with [12.5641] for (0.650, 15.020) cuts
# 	m.values: [5.3593e+08 3.3984e+00], extrapolation: [0.7475]
# 0.65 15.850000000000001 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.650, 15.850) cuts
# 	m.values: [5.3229e+08 3.3562e+00], extrapolation: [0.9564]
# 0.65 16.68 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.650, 16.680) cuts
# 	m.values: [5.3229e+08 3.3562e+00], extrapolation: [0.9564]
# 0.65 17.51 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.650, 17.510) cuts
# 	m.values: [6.9974e+08 3.4135e+00], extrapolation: [0.8915]
# 0.65 18.34 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.650, 18.340) cuts
# 	m.values: [6.9974e+08 3.4135e+00], extrapolation: [0.8915]
# 0.65 19.17 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [45.2497] for (0.650, 19.170) cuts
# 	m.values: [6.8627e+08 3.3843e+00], extrapolation: [1.0418]
# 0.65 20.0 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [45.2497] for (0.650, 20.000) cuts
# 	m.values: [6.8627e+08 3.3843e+00], extrapolation: [1.0418]
# ['QCD_Pt_MuEnriched', 'VV'] with [0.0019 0.0007] for (0.725, 4.230) cuts
# 	m.values: [79.0055  2.6948], extrapolation: [5.0956e-05 7.5092e-06]
# ['TTJets'] with [1.2253] for (0.725, 5.060) cuts
# 	m.values: [6.4510e+04 2.4574e+00], extrapolation: [0.0255]
# ['TTJets'] with [2.859] for (0.725, 5.890) cuts
# 	m.values: [2.3228e+04 1.8178e+00], extrapolation: [0.4257]
# ['TTJets'] with [3.2675] for (0.725, 6.720) cuts
# 	m.values: [7.0389e+04 1.9736e+00], extrapolation: [0.5068]
# ['TTJets'] with [7.7603] for (0.725, 7.550) cuts
# 	m.values: [2.0688e+05 2.0109e+00], extrapolation: [1.1906]
# ['TTJets'] with [11.4362] for (0.725, 8.380) cuts
# 	m.values: [3.9850e+05 2.0747e+00], extrapolation: [1.5639]
# ['TTJets'] with [11.4362] for (0.725, 9.210) cuts
# 	m.values: [3.9850e+05 2.0747e+00], extrapolation: [1.5639]
# ['WJets_all'] with [0.0564] for (0.725, 10.040) cuts
# 	m.values: [224.7188   1.6173], extrapolation: [0.0137]
# ['DY_NLO_all'] with [12.5641] for (0.725, 10.870) cuts
# 	m.values: [2.2657e+08 3.2953e+00], extrapolation: [0.5866]
# ['DY_NLO_all'] with [12.5641] for (0.725, 11.700) cuts
# 	m.values: [2.2680e+08 3.2274e+00], extrapolation: [0.8827]
# ['DY_NLO_all'] with [12.5641] for (0.725, 12.530) cuts
# 	m.values: [2.2680e+08 3.2274e+00], extrapolation: [0.8827]
# ['DY_NLO_all'] with [12.5641] for (0.725, 13.360) cuts
# 	m.values: [3.4914e+08 3.3117e+00], extrapolation: [0.8196]
# ['DY_NLO_all'] with [12.5641] for (0.725, 14.190) cuts
# 	m.values: [5.3593e+08 3.3984e+00], extrapolation: [0.7475]
# ['DY_NLO_all'] with [12.5641] for (0.725, 15.020) cuts
# 	m.values: [5.3593e+08 3.3984e+00], extrapolation: [0.7475]
# 0.725 15.850000000000001 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.725, 15.850) cuts
# 	m.values: [5.3229e+08 3.3562e+00], extrapolation: [0.9564]
# 0.725 16.68 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.725, 16.680) cuts
# 	m.values: [5.3229e+08 3.3562e+00], extrapolation: [0.9564]
# 0.725 17.51 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.725, 17.510) cuts
# 	m.values: [6.9974e+08 3.4135e+00], extrapolation: [0.8915]
# 0.725 18.34 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [30.1665] for (0.725, 18.340) cuts
# 	m.values: [6.9974e+08 3.4135e+00], extrapolation: [0.8915]
# 0.725 19.17 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [45.2497] for (0.725, 19.170) cuts
# 	m.values: [6.8627e+08 3.3843e+00], extrapolation: [1.0418]
# 0.725 20.0 ST_2018 -0.04841298347930524
# ['DY_NLO_all'] with [45.2497] for (0.725, 20.000) cuts
# 	m.values: [6.8627e+08 3.3843e+00], extrapolation: [1.0418]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (0.800, 4.230) cuts
# 	m.values: [367.053    2.6184], extrapolation: [5.5175e-05]
# Warning: fit not accurate or valid!!!
# ['TTJets'] with [1.2253] for (0.800, 5.060) cuts
# 	m.values: [8.8949e+04 2.6348e+00], extrapolation: [0.0121]
# ['TTJets'] with [2.859] for (0.800, 5.890) cuts
# 	m.values: [1.2023e+04 1.6834e+00], extrapolation: [0.4936]
# ['TTJets'] with [3.2675] for (0.800, 6.720) cuts
# 	m.values: [2.9551e+04 1.7885e+00], extrapolation: [0.6461]
# ['TTJets'] with [8.9856] for (0.800, 7.550) cuts
# 	m.values: [8.3249e+04 1.8144e+00], extrapolation: [1.5579]
# ['TTJets'] with [12.6615] for (0.800, 8.380) cuts
# 	m.values: [1.9551e+05 1.9384e+00], extrapolation: [1.7388]
# ['TTJets'] with [12.6615] for (0.800, 9.210) cuts
# 	m.values: [1.9551e+05 1.9384e+00], extrapolation: [1.7388]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0564] for (0.800, 10.040) cuts
# 	m.values: [146.302    1.5383], extrapolation: [0.0143]
# ['DY_NLO_all'] with [12.5641] for (0.800, 10.870) cuts
# 	m.values: [6.8000e+07 3.0384e+00], extrapolation: [0.8227]
# ['DY_NLO_all'] with [12.5641] for (0.800, 11.700) cuts
# 	m.values: [6.6983e+07 2.9603e+00], extrapolation: [1.2943]
# ['DY_NLO_all'] with [12.5641] for (0.800, 12.530) cuts
# 	m.values: [6.6983e+07 2.9603e+00], extrapolation: [1.2943]
# ['DY_NLO_all'] with [12.5641] for (0.800, 13.360) cuts
# 	m.values: [1.1564e+08 3.0746e+00], extrapolation: [1.1258]
# ['DY_NLO_all'] with [12.5641] for (0.800, 14.190) cuts
# 	m.values: [1.9489e+08 3.1917e+00], extrapolation: [0.9396]
# ['DY_NLO_all'] with [12.5641] for (0.800, 15.020) cuts
# 	m.values: [1.9489e+08 3.1917e+00], extrapolation: [0.9396]
# ['DY_NLO_all'] with [30.1665] for (0.800, 15.850) cuts
# 	m.values: [2.0194e+08 3.1622e+00], extrapolation: [1.1624]
# ['DY_NLO_all'] with [30.1665] for (0.800, 16.680) cuts
# 	m.values: [2.0194e+08 3.1622e+00], extrapolation: [1.1624]
# ['DY_NLO_all'] with [30.1665] for (0.800, 17.510) cuts
# 	m.values: [2.5871e+08 3.2101e+00], extrapolation: [1.1169]
# ['DY_NLO_all'] with [30.1665] for (0.800, 18.340) cuts
# 	m.values: [2.5871e+08 3.2101e+00], extrapolation: [1.1169]
# Warning: fit not accurate or valid!!!
# ['DY_NLO_all'] with [45.2497] for (0.800, 19.170) cuts
# 	m.values: [4.4286e+04 2.8643e+01], extrapolation: [1.0221e-70]
# Warning: fit not accurate or valid!!!
# ['DY_NLO_all'] with [45.2497] for (0.800, 20.000) cuts
# 	m.values: [4.4286e+04 2.8643e+01], extrapolation: [1.0221e-70]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (0.875, 4.230) cuts
# 	m.values: [367.053    2.6184], extrapolation: [5.5175e-05]
# Warning: fit not accurate or valid!!!
# ['TTJets'] with [1.2253] for (0.875, 5.060) cuts
# 	m.values: [8.8949e+04 2.6348e+00], extrapolation: [0.0121]
# ['TTJets'] with [2.859] for (0.875, 5.890) cuts
# 	m.values: [1.2023e+04 1.6834e+00], extrapolation: [0.4936]
# ['TTJets'] with [3.2675] for (0.875, 6.720) cuts
# 	m.values: [2.9551e+04 1.7885e+00], extrapolation: [0.6461]
# ['TTJets'] with [8.9856] for (0.875, 7.550) cuts
# 	m.values: [8.3249e+04 1.8144e+00], extrapolation: [1.5579]
# ['TTJets'] with [12.6615] for (0.875, 8.380) cuts
# 	m.values: [1.9551e+05 1.9384e+00], extrapolation: [1.7388]
# ['TTJets'] with [12.6615] for (0.875, 9.210) cuts
# 	m.values: [1.9551e+05 1.9384e+00], extrapolation: [1.7388]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0564] for (0.875, 10.040) cuts
# 	m.values: [146.302    1.5383], extrapolation: [0.0143]
# ['DY_NLO_all'] with [12.5641] for (0.875, 10.870) cuts
# 	m.values: [6.8000e+07 3.0384e+00], extrapolation: [0.8227]
# ['DY_NLO_all'] with [12.5641] for (0.875, 11.700) cuts
# 	m.values: [6.6983e+07 2.9603e+00], extrapolation: [1.2943]
# ['DY_NLO_all'] with [12.5641] for (0.875, 12.530) cuts
# 	m.values: [6.6983e+07 2.9603e+00], extrapolation: [1.2943]
# ['DY_NLO_all'] with [12.5641] for (0.875, 13.360) cuts
# 	m.values: [1.1564e+08 3.0746e+00], extrapolation: [1.1258]
# ['DY_NLO_all'] with [12.5641] for (0.875, 14.190) cuts
# 	m.values: [1.9489e+08 3.1917e+00], extrapolation: [0.9396]
# ['DY_NLO_all'] with [12.5641] for (0.875, 15.020) cuts
# 	m.values: [1.9489e+08 3.1917e+00], extrapolation: [0.9396]
# ['DY_NLO_all'] with [30.1665] for (0.875, 15.850) cuts
# 	m.values: [2.0194e+08 3.1622e+00], extrapolation: [1.1624]
# ['DY_NLO_all'] with [30.1665] for (0.875, 16.680) cuts
# 	m.values: [2.0194e+08 3.1622e+00], extrapolation: [1.1624]
# ['DY_NLO_all'] with [30.1665] for (0.875, 17.510) cuts
# 	m.values: [2.5871e+08 3.2101e+00], extrapolation: [1.1169]
# ['DY_NLO_all'] with [30.1665] for (0.875, 18.340) cuts
# 	m.values: [2.5871e+08 3.2101e+00], extrapolation: [1.1169]
# Warning: fit not accurate or valid!!!
# ['DY_NLO_all'] with [45.2497] for (0.875, 19.170) cuts
# 	m.values: [4.4286e+04 2.8643e+01], extrapolation: [1.0221e-70]
# Warning: fit not accurate or valid!!!
# ['DY_NLO_all'] with [45.2497] for (0.875, 20.000) cuts
# 	m.values: [4.4286e+04 2.8643e+01], extrapolation: [1.0221e-70]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (0.950, 4.230) cuts
# 	m.values: [290.7464   2.598 ], extrapolation: [4.9392e-05]
# ['TTJets'] with [1.2253] for (0.950, 5.060) cuts
# 	m.values: [4.5846e+04 2.5647e+00], extrapolation: [0.0095]
# ['TTJets'] with [2.0422] for (0.950, 5.890) cuts
# 	m.values: [1.0153e+04 1.7408e+00], extrapolation: [0.2954]
# ['TTJets'] with [2.0422] for (0.950, 6.720) cuts
# 	m.values: [1.7700e+04 1.7586e+00], extrapolation: [0.4628]
# ['TTJets'] with [5.7181] for (0.950, 7.550) cuts
# 	m.values: [5.1452e+04 1.7719e+00], extrapolation: [1.2422]
# ['TTJets'] with [8.5771] for (0.950, 8.380) cuts
# 	m.values: [1.1585e+05 1.8881e+00], extrapolation: [1.3928]
# ['TTJets'] with [8.5771] for (0.950, 9.210) cuts
# 	m.values: [1.1585e+05 1.8881e+00], extrapolation: [1.3928]
# ['WJets_all'] with [0.0564] for (0.950, 10.040) cuts
# 	m.values: [98.9113  1.4959], extrapolation: [0.0125]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0564] for (0.950, 10.870) cuts
# 	m.values: [132.0374   1.5174], extrapolation: [0.0147]
# ['WJets_all'] with [0.0824] for (0.950, 11.700) cuts
# 	m.values: [221.652    1.5635], extrapolation: [0.0187]
# ['WJets_all'] with [0.0824] for (0.950, 12.530) cuts
# 	m.values: [221.652    1.5635], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0824] for (0.950, 13.360) cuts
# 	m.values: [312.1538   1.5924], extrapolation: [0.0221]
# ['WJets_all'] with [0.0899] for (0.950, 14.190) cuts
# 	m.values: [613.01     1.7189], extrapolation: [0.0203]
# ['WJets_all'] with [0.0899] for (0.950, 15.020) cuts
# 	m.values: [613.01     1.7189], extrapolation: [0.0203]
# ['DY_NLO_all'] with [15.0832] for (0.950, 15.850) cuts
# 	m.values: [3.3636e+07 2.7967e+00], extrapolation: [1.7351]
# ['DY_NLO_all'] with [15.0832] for (0.950, 16.680) cuts
# 	m.values: [3.3636e+07 2.7967e+00], extrapolation: [1.7351]
# ['DY_NLO_all'] with [15.0832] for (0.950, 17.510) cuts
# 	m.values: [4.5231e+07 2.8571e+00], extrapolation: [1.6241]
# ['DY_NLO_all'] with [15.0832] for (0.950, 18.340) cuts
# 	m.values: [4.5231e+07 2.8571e+00], extrapolation: [1.6241]
# ['DY_NLO_all'] with [15.0832] for (0.950, 19.170) cuts
# 	m.values: [6.0403e+07 2.9302e+00], extrapolation: [1.3986]
# ['DY_NLO_all'] with [15.0832] for (0.950, 20.000) cuts
# 	m.values: [6.0403e+07 2.9302e+00], extrapolation: [1.3986]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.025, 4.230) cuts
# 	m.values: [290.7464   2.598 ], extrapolation: [4.9392e-05]
# ['TTJets'] with [1.2253] for (1.025, 5.060) cuts
# 	m.values: [4.5846e+04 2.5647e+00], extrapolation: [0.0095]
# ['TTJets'] with [2.0422] for (1.025, 5.890) cuts
# 	m.values: [1.0153e+04 1.7408e+00], extrapolation: [0.2954]
# ['TTJets'] with [2.0422] for (1.025, 6.720) cuts
# 	m.values: [1.7700e+04 1.7586e+00], extrapolation: [0.4628]
# ['TTJets'] with [5.7181] for (1.025, 7.550) cuts
# 	m.values: [5.1452e+04 1.7719e+00], extrapolation: [1.2422]
# ['TTJets'] with [8.5771] for (1.025, 8.380) cuts
# 	m.values: [1.1585e+05 1.8881e+00], extrapolation: [1.3928]
# ['TTJets'] with [8.5771] for (1.025, 9.210) cuts
# 	m.values: [1.1585e+05 1.8881e+00], extrapolation: [1.3928]
# ['WJets_all'] with [0.0564] for (1.025, 10.040) cuts
# 	m.values: [98.9113  1.4959], extrapolation: [0.0125]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0564] for (1.025, 10.870) cuts
# 	m.values: [132.0374   1.5174], extrapolation: [0.0147]
# ['WJets_all'] with [0.0824] for (1.025, 11.700) cuts
# 	m.values: [221.652    1.5635], extrapolation: [0.0187]
# ['WJets_all'] with [0.0824] for (1.025, 12.530) cuts
# 	m.values: [221.652    1.5635], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0824] for (1.025, 13.360) cuts
# 	m.values: [312.1538   1.5924], extrapolation: [0.0221]
# ['WJets_all'] with [0.0899] for (1.025, 14.190) cuts
# 	m.values: [613.01     1.7189], extrapolation: [0.0203]
# ['WJets_all'] with [0.0899] for (1.025, 15.020) cuts
# 	m.values: [613.01     1.7189], extrapolation: [0.0203]
# ['DY_NLO_all'] with [15.0832] for (1.025, 15.850) cuts
# 	m.values: [3.3636e+07 2.7967e+00], extrapolation: [1.7351]
# ['DY_NLO_all'] with [15.0832] for (1.025, 16.680) cuts
# 	m.values: [3.3636e+07 2.7967e+00], extrapolation: [1.7351]
# ['DY_NLO_all'] with [15.0832] for (1.025, 17.510) cuts
# 	m.values: [4.5231e+07 2.8571e+00], extrapolation: [1.6241]
# ['DY_NLO_all'] with [15.0832] for (1.025, 18.340) cuts
# 	m.values: [4.5231e+07 2.8571e+00], extrapolation: [1.6241]
# ['DY_NLO_all'] with [15.0832] for (1.025, 19.170) cuts
# 	m.values: [6.0403e+07 2.9302e+00], extrapolation: [1.3986]
# ['DY_NLO_all'] with [15.0832] for (1.025, 20.000) cuts
# 	m.values: [6.0403e+07 2.9302e+00], extrapolation: [1.3986]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.100, 4.230) cuts
# 	m.values: [418.7583   2.8317], extrapolation: [1.7504e-05]
# Warning: fit not accurate or valid!!!
# ['TTJets'] with [1.2253] for (1.100, 5.060) cuts
# 	m.values: [5.7097e+06 4.2478e+00], extrapolation: [4.8728e-05]
# ['TTJets'] with [1.6337] for (1.100, 5.890) cuts
# 	m.values: [4.1212e+03 1.5742e+00], extrapolation: [0.3259]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.100, 6.720) cuts
# 	m.values: [7.3028e+03 1.6195e+00], extrapolation: [0.4399]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [5.3097] for (1.100, 7.550) cuts
# 	m.values: [1.8674e+04 1.5916e+00], extrapolation: [1.3297]
# 1.1 8.38 TTJets_2018 -0.4084351181574274
# ['TTJets'] with [5.7181] for (1.100, 8.380) cuts
# 	m.values: [5.4342e+04 1.8035e+00], extrapolation: [1.0852]
# 1.1 9.21 TTJets_2018 -0.4084351181574274
# ['TTJets'] with [5.7181] for (1.100, 9.210) cuts
# 	m.values: [5.4342e+04 1.8035e+00], extrapolation: [1.0852]
# ['TTJets'] with [6.535] for (1.100, 10.040) cuts
# 	m.values: [7.5361e+04 1.8001e+00], extrapolation: [1.5362]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [7.3518] for (1.100, 10.870) cuts
# 	m.values: [1.2465e+05 1.8506e+00], extrapolation: [1.8766]
# ['WJets_all'] with [0.0824] for (1.100, 11.700) cuts
# 	m.values: [133.8892   1.4783], extrapolation: [0.0188]
# ['WJets_all'] with [0.0824] for (1.100, 12.530) cuts
# 	m.values: [133.8892   1.4783], extrapolation: [0.0188]
# 1.1 13.360000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [11.8446] for (1.100, 13.360) cuts
# 	m.values: [2.2465e+05 1.8482e+00], extrapolation: [3.4314]
# 1.1 14.190000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [16.7458] for (1.100, 14.190) cuts
# 	m.values: [2.9315e+05 1.8504e+00], extrapolation: [4.4192]
# 1.1 15.020000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [16.7458] for (1.100, 15.020) cuts
# 	m.values: [2.9315e+05 1.8504e+00], extrapolation: [4.4192]
# 1.1 15.850000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [20.0133 15.0832] for (1.100, 15.850) cuts
# 	m.values: [2.8132e+06 2.3088e+00], extrapolation: [5.6361 2.71  ]
# 1.1 16.68 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [20.0133 15.0832] for (1.100, 16.680) cuts
# 	m.values: [2.8132e+06 2.3088e+00], extrapolation: [5.6361 2.71  ]
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [27.7736 12.5641] for (1.100, 17.510) cuts
# 	m.values: [4.7682e+06 2.4335e+00], extrapolation: [7.1665 2.1743]
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [27.7736 12.5641] for (1.100, 18.340) cuts
# 	m.values: [4.7682e+06 2.4335e+00], extrapolation: [7.1665 2.1743]
# ['DY_NLO_all'] with [12.5641] for (1.100, 19.170) cuts
# 	m.values: [6.2086e+06 2.4949e+00], extrapolation: [1.9579]
# ['DY_NLO_all'] with [12.5641] for (1.100, 20.000) cuts
# 	m.values: [6.2086e+06 2.4949e+00], extrapolation: [1.9579]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.175, 4.230) cuts
# 	m.values: [418.7583   2.8317], extrapolation: [1.7504e-05]
# Warning: fit not accurate or valid!!!
# ['TTJets'] with [1.2253] for (1.175, 5.060) cuts
# 	m.values: [5.7097e+06 4.2478e+00], extrapolation: [4.8728e-05]
# ['TTJets'] with [1.6337] for (1.175, 5.890) cuts
# 	m.values: [4.1212e+03 1.5742e+00], extrapolation: [0.3259]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.175, 6.720) cuts
# 	m.values: [7.3028e+03 1.6195e+00], extrapolation: [0.4399]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [5.3097] for (1.175, 7.550) cuts
# 	m.values: [1.8674e+04 1.5916e+00], extrapolation: [1.3297]
# 1.1749999999999998 8.38 TTJets_2018 -0.4084351181574274
# ['TTJets'] with [5.7181] for (1.175, 8.380) cuts
# 	m.values: [5.4342e+04 1.8035e+00], extrapolation: [1.0852]
# 1.1749999999999998 9.21 TTJets_2018 -0.4084351181574274
# ['TTJets'] with [5.7181] for (1.175, 9.210) cuts
# 	m.values: [5.4342e+04 1.8035e+00], extrapolation: [1.0852]
# ['TTJets'] with [6.535] for (1.175, 10.040) cuts
# 	m.values: [7.5361e+04 1.8001e+00], extrapolation: [1.5362]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [7.3518] for (1.175, 10.870) cuts
# 	m.values: [1.2465e+05 1.8506e+00], extrapolation: [1.8766]
# ['WJets_all'] with [0.0824] for (1.175, 11.700) cuts
# 	m.values: [133.8892   1.4783], extrapolation: [0.0188]
# ['WJets_all'] with [0.0824] for (1.175, 12.530) cuts
# 	m.values: [133.8892   1.4783], extrapolation: [0.0188]
# 1.1749999999999998 13.360000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [11.8446] for (1.175, 13.360) cuts
# 	m.values: [2.2465e+05 1.8482e+00], extrapolation: [3.4314]
# 1.1749999999999998 14.190000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [16.7458] for (1.175, 14.190) cuts
# 	m.values: [2.9315e+05 1.8504e+00], extrapolation: [4.4192]
# 1.1749999999999998 15.020000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [16.7458] for (1.175, 15.020) cuts
# 	m.values: [2.9315e+05 1.8504e+00], extrapolation: [4.4192]
# 1.1749999999999998 15.850000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [20.0133 15.0832] for (1.175, 15.850) cuts
# 	m.values: [2.8132e+06 2.3088e+00], extrapolation: [5.6361 2.71  ]
# 1.1749999999999998 16.68 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [20.0133 15.0832] for (1.175, 16.680) cuts
# 	m.values: [2.8132e+06 2.3088e+00], extrapolation: [5.6361 2.71  ]
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [27.7736 12.5641] for (1.175, 17.510) cuts
# 	m.values: [4.7682e+06 2.4335e+00], extrapolation: [7.1665 2.1743]
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [27.7736 12.5641] for (1.175, 18.340) cuts
# 	m.values: [4.7682e+06 2.4335e+00], extrapolation: [7.1665 2.1743]
# ['DY_NLO_all'] with [12.5641] for (1.175, 19.170) cuts
# 	m.values: [6.2086e+06 2.4949e+00], extrapolation: [1.9579]
# ['DY_NLO_all'] with [12.5641] for (1.175, 20.000) cuts
# 	m.values: [6.2086e+06 2.4949e+00], extrapolation: [1.9579]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.250, 4.230) cuts
# 	m.values: [418.7583   2.8317], extrapolation: [1.7504e-05]
# Warning: fit not accurate or valid!!!
# ['TTJets'] with [1.2253] for (1.250, 5.060) cuts
# 	m.values: [5.7097e+06 4.2478e+00], extrapolation: [4.8728e-05]
# ['TTJets'] with [1.6337] for (1.250, 5.890) cuts
# 	m.values: [4.1212e+03 1.5742e+00], extrapolation: [0.3259]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.250, 6.720) cuts
# 	m.values: [7.3028e+03 1.6195e+00], extrapolation: [0.4399]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [5.3097] for (1.250, 7.550) cuts
# 	m.values: [1.8674e+04 1.5916e+00], extrapolation: [1.3297]
# 1.25 8.38 TTJets_2018 -0.4084351181574274
# ['TTJets'] with [5.7181] for (1.250, 8.380) cuts
# 	m.values: [5.4342e+04 1.8035e+00], extrapolation: [1.0852]
# 1.25 9.21 TTJets_2018 -0.4084351181574274
# ['TTJets'] with [5.7181] for (1.250, 9.210) cuts
# 	m.values: [5.4342e+04 1.8035e+00], extrapolation: [1.0852]
# ['TTJets'] with [6.535] for (1.250, 10.040) cuts
# 	m.values: [7.5361e+04 1.8001e+00], extrapolation: [1.5362]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [7.3518] for (1.250, 10.870) cuts
# 	m.values: [1.2465e+05 1.8506e+00], extrapolation: [1.8766]
# ['WJets_all'] with [0.0824] for (1.250, 11.700) cuts
# 	m.values: [133.8892   1.4783], extrapolation: [0.0188]
# ['WJets_all'] with [0.0824] for (1.250, 12.530) cuts
# 	m.values: [133.8892   1.4783], extrapolation: [0.0188]
# 1.25 13.360000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [11.8446] for (1.250, 13.360) cuts
# 	m.values: [2.2465e+05 1.8482e+00], extrapolation: [3.4314]
# 1.25 14.190000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [16.7458] for (1.250, 14.190) cuts
# 	m.values: [2.9315e+05 1.8504e+00], extrapolation: [4.4192]
# 1.25 15.020000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [16.7458] for (1.250, 15.020) cuts
# 	m.values: [2.9315e+05 1.8504e+00], extrapolation: [4.4192]
# 1.25 15.850000000000001 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [20.0133 15.0832] for (1.250, 15.850) cuts
# 	m.values: [2.8132e+06 2.3088e+00], extrapolation: [5.6361 2.71  ]
# 1.25 16.68 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [20.0133 15.0832] for (1.250, 16.680) cuts
# 	m.values: [2.8132e+06 2.3088e+00], extrapolation: [5.6361 2.71  ]
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [27.7736 12.5641] for (1.250, 17.510) cuts
# 	m.values: [4.7682e+06 2.4335e+00], extrapolation: [7.1665 2.1743]
# Warning!!! Extrapolation is off!!!
# ['TTJets', 'DY_NLO_all'] with [27.7736 12.5641] for (1.250, 18.340) cuts
# 	m.values: [4.7682e+06 2.4335e+00], extrapolation: [7.1665 2.1743]
# ['DY_NLO_all'] with [12.5641] for (1.250, 19.170) cuts
# 	m.values: [6.2086e+06 2.4949e+00], extrapolation: [1.9579]
# ['DY_NLO_all'] with [12.5641] for (1.250, 20.000) cuts
# 	m.values: [6.2086e+06 2.4949e+00], extrapolation: [1.9579]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.325, 4.230) cuts
# 	m.values: [1095.9373    3.2367], extrapolation: [4.0341e-06]
# ['TTJets'] with [0.8169] for (1.325, 5.060) cuts
# 	m.values: [5.5055e+03 2.0581e+00], extrapolation: [0.0239]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.325, 5.890) cuts
# 	m.values: [3.0114e+03 1.5867e+00], extrapolation: [0.2209]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.325, 6.720) cuts
# 	m.values: [5.6756e+03 1.6459e+00], extrapolation: [0.2918]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.325, 7.550) cuts
# 	m.values: [1.6268e+04 1.6706e+00], extrapolation: [0.7212]
# ['TTJets'] with [3.2675] for (1.325, 8.380) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# ['TTJets'] with [3.2675] for (1.325, 9.210) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# Warning!!! Extrapolation is off!!!
# ['WJets_all', 'VV'] with [0.0419 0.0294] for (1.325, 10.040) cuts
# 	m.values: [2.7850e+04 2.6114e+00], extrapolation: [0.0115 0.0044]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0419] for (1.325, 10.870) cuts
# 	m.values: [52.5134  1.3933], extrapolation: [0.0123]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.325, 11.700) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.325, 12.530) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [10.2109] for (1.325, 13.360) cuts
# 	m.values: [8.8814e+04 1.7224e+00], extrapolation: [2.8869]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.325, 14.190) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.325, 15.020) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.325, 15.850) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.325, 16.680) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# ['DY_NLO_all'] with [17.6024] for (1.325, 17.510) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.325, 18.340) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.325, 19.170) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['DY_NLO_all'] with [17.6024] for (1.325, 20.000) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.400, 4.230) cuts
# 	m.values: [1095.9373    3.2367], extrapolation: [4.0341e-06]
# ['TTJets'] with [0.8169] for (1.400, 5.060) cuts
# 	m.values: [5.5055e+03 2.0581e+00], extrapolation: [0.0239]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.400, 5.890) cuts
# 	m.values: [3.0114e+03 1.5867e+00], extrapolation: [0.2209]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.400, 6.720) cuts
# 	m.values: [5.6756e+03 1.6459e+00], extrapolation: [0.2918]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.400, 7.550) cuts
# 	m.values: [1.6268e+04 1.6706e+00], extrapolation: [0.7212]
# ['TTJets'] with [3.2675] for (1.400, 8.380) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# ['TTJets'] with [3.2675] for (1.400, 9.210) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# Warning!!! Extrapolation is off!!!
# ['WJets_all', 'VV'] with [0.0419 0.0294] for (1.400, 10.040) cuts
# 	m.values: [2.7850e+04 2.6114e+00], extrapolation: [0.0115 0.0044]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0419] for (1.400, 10.870) cuts
# 	m.values: [52.5134  1.3933], extrapolation: [0.0123]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.400, 11.700) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.400, 12.530) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [10.2109] for (1.400, 13.360) cuts
# 	m.values: [8.8814e+04 1.7224e+00], extrapolation: [2.8869]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.400, 14.190) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.400, 15.020) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.400, 15.850) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.400, 16.680) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# ['DY_NLO_all'] with [17.6024] for (1.400, 17.510) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.400, 18.340) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.400, 19.170) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['DY_NLO_all'] with [17.6024] for (1.400, 20.000) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.475, 4.230) cuts
# 	m.values: [1095.9373    3.2367], extrapolation: [4.0341e-06]
# ['TTJets'] with [0.8169] for (1.475, 5.060) cuts
# 	m.values: [5.5055e+03 2.0581e+00], extrapolation: [0.0239]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.475, 5.890) cuts
# 	m.values: [3.0114e+03 1.5867e+00], extrapolation: [0.2209]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.475, 6.720) cuts
# 	m.values: [5.6756e+03 1.6459e+00], extrapolation: [0.2918]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.475, 7.550) cuts
# 	m.values: [1.6268e+04 1.6706e+00], extrapolation: [0.7212]
# ['TTJets'] with [3.2675] for (1.475, 8.380) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# ['TTJets'] with [3.2675] for (1.475, 9.210) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# Warning!!! Extrapolation is off!!!
# ['WJets_all', 'VV'] with [0.0419 0.0294] for (1.475, 10.040) cuts
# 	m.values: [2.7850e+04 2.6114e+00], extrapolation: [0.0115 0.0044]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0419] for (1.475, 10.870) cuts
# 	m.values: [52.5134  1.3933], extrapolation: [0.0123]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.475, 11.700) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.475, 12.530) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [10.2109] for (1.475, 13.360) cuts
# 	m.values: [8.8814e+04 1.7224e+00], extrapolation: [2.8869]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.475, 14.190) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.475, 15.020) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.475, 15.850) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.475, 16.680) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# ['DY_NLO_all'] with [17.6024] for (1.475, 17.510) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.475, 18.340) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.475, 19.170) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['DY_NLO_all'] with [17.6024] for (1.475, 20.000) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['QCD_Pt_MuEnriched'] with [0.0019] for (1.550, 4.230) cuts
# 	m.values: [1095.9373    3.2367], extrapolation: [4.0341e-06]
# ['TTJets'] with [0.8169] for (1.550, 5.060) cuts
# 	m.values: [5.5055e+03 2.0581e+00], extrapolation: [0.0239]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.550, 5.890) cuts
# 	m.values: [3.0114e+03 1.5867e+00], extrapolation: [0.2209]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.550, 6.720) cuts
# 	m.values: [5.6756e+03 1.6459e+00], extrapolation: [0.2918]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.550, 7.550) cuts
# 	m.values: [1.6268e+04 1.6706e+00], extrapolation: [0.7212]
# ['TTJets'] with [3.2675] for (1.550, 8.380) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# ['TTJets'] with [3.2675] for (1.550, 9.210) cuts
# 	m.values: [3.3368e+04 1.7833e+00], extrapolation: [0.7522]
# Warning!!! Extrapolation is off!!!
# ['WJets_all', 'VV'] with [0.0419 0.0294] for (1.550, 10.040) cuts
# 	m.values: [2.7850e+04 2.6114e+00], extrapolation: [0.0115 0.0044]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0419] for (1.550, 10.870) cuts
# 	m.values: [52.5134  1.3933], extrapolation: [0.0123]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.550, 11.700) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['WJets_all'] with [0.0679] for (1.550, 12.530) cuts
# 	m.values: [67.5428  1.3654], extrapolation: [0.0187]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [10.2109] for (1.550, 13.360) cuts
# 	m.values: [8.8814e+04 1.7224e+00], extrapolation: [2.8869]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.550, 14.190) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [13.0699] for (1.550, 15.020) cuts
# 	m.values: [1.3055e+05 1.7617e+00], extrapolation: [3.352]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.550, 15.850) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024 15.5205] for (1.550, 16.680) cuts
# 	m.values: [1.7805e+05 1.7832e+00], extrapolation: [1.8724 4.0172]
# ['DY_NLO_all'] with [17.6024] for (1.550, 17.510) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.550, 18.340) cuts
# 	m.values: [3.1040e+06 2.4147e+00], extrapolation: [1.584]
# ['DY_NLO_all'] with [17.6024] for (1.550, 19.170) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['DY_NLO_all'] with [17.6024] for (1.550, 20.000) cuts
# 	m.values: [4.3024e+06 2.5009e+00], extrapolation: [1.3087]
# ['QCD_Pt_MuEnriched'] with [0.0007] for (1.625, 4.230) cuts
# 	m.values: [682.6632   3.2259], extrapolation: [2.681e-06]
# ['TTJets'] with [0.8169] for (1.625, 5.060) cuts
# 	m.values: [3.2182e+03 2.0555e+00], extrapolation: [0.0142]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.625, 5.890) cuts
# 	m.values: [529.4015   1.2325], extrapolation: [0.3253]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.625, 6.720) cuts
# 	m.values: [1136.0785    1.317 ], extrapolation: [0.4204]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.625, 7.550) cuts
# 	m.values: [4.536e+03 1.461e+00], extrapolation: [0.7072]
# 1.625 8.38 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.625, 8.380) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# 1.625 9.21 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.625, 9.210) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.625, 10.040) cuts
# 	m.values: [1.5045e+04 1.6350e+00], extrapolation: [0.8259]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.625, 10.870) cuts
# 	m.values: [2.4505e+04 1.7161e+00], extrapolation: [0.8268]
# ['WJets_all'] with [0.0075] for (1.625, 11.700) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# ['WJets_all'] with [0.0075] for (1.625, 12.530) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [4.9012] for (1.625, 13.360) cuts
# 	m.values: [4.9381e+04 1.7522e+00], extrapolation: [1.3417]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.625, 14.190) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.625, 15.020) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.625, 15.850) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.625, 16.680) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# ['DY_NLO_all'] with [17.6024] for (1.625, 17.510) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.625, 18.340) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.625, 19.170) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# ['DY_NLO_all'] with [17.6024] for (1.625, 20.000) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# ['QCD_Pt_MuEnriched'] with [0.0007] for (1.700, 4.230) cuts
# 	m.values: [682.6632   3.2259], extrapolation: [2.681e-06]
# ['TTJets'] with [0.8169] for (1.700, 5.060) cuts
# 	m.values: [3.2182e+03 2.0555e+00], extrapolation: [0.0142]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.700, 5.890) cuts
# 	m.values: [529.4015   1.2325], extrapolation: [0.3253]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.700, 6.720) cuts
# 	m.values: [1136.0785    1.317 ], extrapolation: [0.4204]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.700, 7.550) cuts
# 	m.values: [4.536e+03 1.461e+00], extrapolation: [0.7072]
# 1.7 8.38 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.700, 8.380) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# 1.7 9.21 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.700, 9.210) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.700, 10.040) cuts
# 	m.values: [1.5045e+04 1.6350e+00], extrapolation: [0.8259]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.700, 10.870) cuts
# 	m.values: [2.4505e+04 1.7161e+00], extrapolation: [0.8268]
# ['WJets_all'] with [0.0075] for (1.700, 11.700) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# ['WJets_all'] with [0.0075] for (1.700, 12.530) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [4.9012] for (1.700, 13.360) cuts
# 	m.values: [4.9381e+04 1.7522e+00], extrapolation: [1.3417]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.700, 14.190) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.700, 15.020) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.700, 15.850) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.700, 16.680) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# ['DY_NLO_all'] with [17.6024] for (1.700, 17.510) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.700, 18.340) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.700, 19.170) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# ['DY_NLO_all'] with [17.6024] for (1.700, 20.000) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# ['QCD_Pt_MuEnriched'] with [0.0007] for (1.775, 4.230) cuts
# 	m.values: [682.6632   3.2259], extrapolation: [2.681e-06]
# ['TTJets'] with [0.8169] for (1.775, 5.060) cuts
# 	m.values: [3.2182e+03 2.0555e+00], extrapolation: [0.0142]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.775, 5.890) cuts
# 	m.values: [529.4015   1.2325], extrapolation: [0.3253]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.775, 6.720) cuts
# 	m.values: [1136.0785    1.317 ], extrapolation: [0.4204]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.775, 7.550) cuts
# 	m.values: [4.536e+03 1.461e+00], extrapolation: [0.7072]
# 1.775 8.38 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.775, 8.380) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# 1.775 9.21 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.775, 9.210) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.775, 10.040) cuts
# 	m.values: [1.5045e+04 1.6350e+00], extrapolation: [0.8259]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.775, 10.870) cuts
# 	m.values: [2.4505e+04 1.7161e+00], extrapolation: [0.8268]
# ['WJets_all'] with [0.0075] for (1.775, 11.700) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# ['WJets_all'] with [0.0075] for (1.775, 12.530) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [4.9012] for (1.775, 13.360) cuts
# 	m.values: [4.9381e+04 1.7522e+00], extrapolation: [1.3417]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.775, 14.190) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.775, 15.020) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.775, 15.850) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.775, 16.680) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# ['DY_NLO_all'] with [17.6024] for (1.775, 17.510) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.775, 18.340) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.775, 19.170) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# ['DY_NLO_all'] with [17.6024] for (1.775, 20.000) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# ['QCD_Pt_MuEnriched'] with [0.0007] for (1.850, 4.230) cuts
# 	m.values: [682.6632   3.2259], extrapolation: [2.681e-06]
# ['TTJets'] with [0.8169] for (1.850, 5.060) cuts
# 	m.values: [3.2182e+03 2.0555e+00], extrapolation: [0.0142]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.850, 5.890) cuts
# 	m.values: [529.4015   1.2325], extrapolation: [0.3253]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.850, 6.720) cuts
# 	m.values: [1136.0785    1.317 ], extrapolation: [0.4204]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.850, 7.550) cuts
# 	m.values: [4.536e+03 1.461e+00], extrapolation: [0.7072]
# 1.8499999999999999 8.38 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.850, 8.380) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# 1.8499999999999999 9.21 TTJets_2018 -0.4084351181574274
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.850, 9.210) cuts
# 	m.values: [1.5811e+04 1.7373e+00], extrapolation: [0.47]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.850, 10.040) cuts
# 	m.values: [1.5045e+04 1.6350e+00], extrapolation: [0.8259]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.850, 10.870) cuts
# 	m.values: [2.4505e+04 1.7161e+00], extrapolation: [0.8268]
# ['WJets_all'] with [0.0075] for (1.850, 11.700) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# ['WJets_all'] with [0.0075] for (1.850, 12.530) cuts
# 	m.values: [453.9713   2.0933], extrapolation: [0.0016]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [4.9012] for (1.850, 13.360) cuts
# 	m.values: [4.9381e+04 1.7522e+00], extrapolation: [1.3417]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.850, 14.190) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [6.1265] for (1.850, 15.020) cuts
# 	m.values: [7.0154e+04 1.7821e+00], extrapolation: [1.5932]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.850, 15.850) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# Warning!!! Extrapolation is off!!!
# ['DY_NLO_all', 'TTJets'] with [17.6024  7.3518] for (1.850, 16.680) cuts
# 	m.values: [9.1478e+04 1.7954e+00], extrapolation: [0.9852 1.9182]
# ['DY_NLO_all'] with [17.6024] for (1.850, 17.510) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.850, 18.340) cuts
# 	m.values: [1.2425e+06 2.3144e+00], extrapolation: [1.1577]
# ['DY_NLO_all'] with [17.6024] for (1.850, 19.170) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# ['DY_NLO_all'] with [17.6024] for (1.850, 20.000) cuts
# 	m.values: [1.5140e+06 2.3541e+00], extrapolation: [1.1116]
# Warning: fit not accurate or valid!!!
# ['QCD_Pt_MuEnriched'] with [0.0007] for (1.925, 4.230) cuts
# 	m.values: [100000.     nan], extrapolation: [nan]
# ['TTJets'] with [0.8169] for (1.925, 5.060) cuts
# 	m.values: [49.7213  1.0003], extrapolation: [0.123]
# ['TTJets'] with [0.8169] for (1.925, 5.890) cuts
# 	m.values: [1326.9804    1.7458], extrapolation: [0.0375]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (1.925, 6.720) cuts
# 	m.values: [241.9576   1.1046], extrapolation: [0.3202]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.925, 7.550) cuts
# 	m.values: [632.7125   1.1159], extrapolation: [0.7825]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.925, 8.380) cuts
# 	m.values: [1.8341e+03 1.3494e+00], extrapolation: [0.5588]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (1.925, 9.210) cuts
# 	m.values: [1.8341e+03 1.3494e+00], extrapolation: [0.5588]
# ['TTJets'] with [2.0422] for (1.925, 10.040) cuts
# 	m.values: [3.4421e+03 1.4694e+00], extrapolation: [0.5104]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (1.925, 10.870) cuts
# 	m.values: [7.7232e+03 1.6375e+00], extrapolation: [0.4178]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [3.2675] for (1.925, 11.700) cuts
# 	m.values: [5.0239e+03 1.4278e+00], extrapolation: [0.9559]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [3.2675] for (1.925, 12.530) cuts
# 	m.values: [5.0239e+03 1.4278e+00], extrapolation: [0.9559]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [3.2675] for (1.925, 13.360) cuts
# 	m.values: [1.2293e+04 1.5960e+00], extrapolation: [0.8526]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.925, 14.190) cuts
# 	m.values: [2.0102e+04 1.7019e+00], extrapolation: [0.7389]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (1.925, 15.020) cuts
# 	m.values: [2.0102e+04 1.7019e+00], extrapolation: [0.7389]
# Warning: fit not accurate or valid!!!
# ['TTJets', 'DY_NLO_all'] with [2.859  2.5192] for (1.925, 15.850) cuts
# 	m.values: [2.2399e+04 1.7767e+00], extrapolation: [0.9073 0.5255]
# Warning: fit not accurate or valid!!!
# ['TTJets', 'DY_NLO_all'] with [2.859  2.5192] for (1.925, 16.680) cuts
# 	m.values: [2.2399e+04 1.7767e+00], extrapolation: [0.9073 0.5255]
# ['DY_NLO_all'] with [2.5192] for (1.925, 17.510) cuts
# 	m.values: [5.4046e+04 1.9504e+00], extrapolation: [0.4473]
# ['DY_NLO_all'] with [2.5192] for (1.925, 18.340) cuts
# 	m.values: [5.4046e+04 1.9504e+00], extrapolation: [0.4473]
# ['DY_NLO_all'] with [2.5192] for (1.925, 19.170) cuts
# 	m.values: [5.3040e+04 1.9407e+00], extrapolation: [0.4653]
# ['DY_NLO_all'] with [2.5192] for (1.925, 20.000) cuts
# 	m.values: [5.3040e+04 1.9407e+00], extrapolation: [0.4653]
# Warning: fit not accurate or valid!!!
# ['QCD_Pt_MuEnriched'] with [0.0007] for (2.000, 4.230) cuts
# 	m.values: [100000.     nan], extrapolation: [nan]
# ['TTJets'] with [0.8169] for (2.000, 5.060) cuts
# 	m.values: [49.7213  1.0003], extrapolation: [0.123]
# ['TTJets'] with [0.8169] for (2.000, 5.890) cuts
# 	m.values: [1326.9804    1.7458], extrapolation: [0.0375]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [0.8169] for (2.000, 6.720) cuts
# 	m.values: [241.9576   1.1046], extrapolation: [0.3202]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (2.000, 7.550) cuts
# 	m.values: [632.7125   1.1159], extrapolation: [0.7825]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (2.000, 8.380) cuts
# 	m.values: [1.8341e+03 1.3494e+00], extrapolation: [0.5588]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.0422] for (2.000, 9.210) cuts
# 	m.values: [1.8341e+03 1.3494e+00], extrapolation: [0.5588]
# ['TTJets'] with [2.0422] for (2.000, 10.040) cuts
# 	m.values: [3.4421e+03 1.4694e+00], extrapolation: [0.5104]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [1.6337] for (2.000, 10.870) cuts
# 	m.values: [7.7232e+03 1.6375e+00], extrapolation: [0.4178]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [3.2675] for (2.000, 11.700) cuts
# 	m.values: [5.0239e+03 1.4278e+00], extrapolation: [0.9559]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [3.2675] for (2.000, 12.530) cuts
# 	m.values: [5.0239e+03 1.4278e+00], extrapolation: [0.9559]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [3.2675] for (2.000, 13.360) cuts
# 	m.values: [1.2293e+04 1.5960e+00], extrapolation: [0.8526]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (2.000, 14.190) cuts
# 	m.values: [2.0102e+04 1.7019e+00], extrapolation: [0.7389]
# Warning!!! Extrapolation is off!!!
# ['TTJets'] with [2.4506] for (2.000, 15.020) cuts
# 	m.values: [2.0102e+04 1.7019e+00], extrapolation: [0.7389]
# Warning: fit not accurate or valid!!!
# ['TTJets', 'DY_NLO_all'] with [2.859  2.5192] for (2.000, 15.850) cuts
# 	m.values: [2.2399e+04 1.7767e+00], extrapolation: [0.9073 0.5255]
# Warning: fit not accurate or valid!!!
# ['TTJets', 'DY_NLO_all'] with [2.859  2.5192] for (2.000, 16.680) cuts
# 	m.values: [2.2399e+04 1.7767e+00], extrapolation: [0.9073 0.5255]
# ['DY_NLO_all'] with [2.5192] for (2.000, 17.510) cuts
# 	m.values: [5.4046e+04 1.9504e+00], extrapolation: [0.4473]
# ['DY_NLO_all'] with [2.5192] for (2.000, 18.340) cuts
# 	m.values: [5.4046e+04 1.9504e+00], extrapolation: [0.4473]
# ['DY_NLO_all'] with [2.5192] for (2.000, 19.170) cuts
# 	m.values: [5.3040e+04 1.9407e+00], extrapolation: [0.4653]
# ['DY_NLO_all'] with [2.5192] for (2.000, 20.000) cuts
# 	m.values: [5.3040e+04 1.9407e+00], extrapolation: [0.4653]

# %%
m
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 0.5977 (χ²/ndof = 0.6)     │              Nfcn = 148              │
# │ EDM = 1.46e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ A    │  0.05e6   │  0.08e6   │            │            │         │         │       │
# │ 1 │ B    │    1.9    │    0.4    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬───────────────────────┐
# │   │          A          B │
# ├───┼───────────────────────┤
# │ A │   7.16e+09 34.61801e3 │
# │ B │ 34.61801e3      0.178 │
# └───┴───────────────────────┘

# %%
m.accurate
# Out:
# 0.597657175648531

# %%
# Significance scans using all
for signal in signals:
    print(f"Results for {signal}")
    s_i = S[signal]
    eff_i = S[signal]/S_tot[signal]
    fig, axs = plt.subplots(2, 3, figsize=(30, 20))
    
    #sig = S_over_SB(s_i, B)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[0, 0])
    #axs[0, 0].set_xlabel('l_muon_iso cut')
    #axs[0, 0].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_over_SB")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    #sig = S_12(s_i, B)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[0, 1])
    #axs[0, 1].set_xlabel('l_muon_iso cut')
    #axs[0, 1].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_12")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 0)
    sig = asimov_sig(s_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("asimov")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    #sig = S_over_BdB(s_i, B, deltaB2)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[1, 0])
    #axs[1, 0].set_xlabel('l_muon_iso cut')
    #axs[1, 0].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_over_BdB")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 1)
    sig = punzi(eff_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 2)
    sig = punzi_imp(eff_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi_imp")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (1, 0)
    sig = punzi(eff_i, B, a=5)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi a=5")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (1, 1)
    sig = punzi_imp(eff_i, B, a=5)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi_imp a=5")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    plt.tight_layout()
    plt.show()
# Out:
# Results for SUEP-m125-darkPho_2018
# Results for SUEP-m400-darkPho_2018
# Results for SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018
# Results for SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018

# %%
# Significance scans using only non-negative B
for signal in signals:
    print(f"Results for {signal}")
    s_i = S[signal]
    eff_i = S[signal]/S_tot[signal]
    fig, axs = plt.subplots(2, 3, figsize=(30, 20))
    
    #sig = S_over_SB(s_i, B)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[0, 0])
    #axs[0, 0].set_xlabel('l_muon_iso cut')
    #axs[0, 0].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_over_SB")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    #sig = S_12(s_i, B)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[0, 1])
    #axs[0, 1].set_xlabel('l_muon_iso cut')
    #axs[0, 1].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_12")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 0)
    sig = asimov_sig(s_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("asimov")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    #sig = S_over_BdB(s_i, B, deltaB2)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[1, 0])
    #axs[1, 0].set_xlabel('l_muon_iso cut')
    #axs[1, 0].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_over_BdB")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 1)
    sig = punzi(eff_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 2)
    sig = punzi_imp(eff_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi_imp")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (1, 0)
    sig = punzi(eff_i, B, a=5)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi a=5")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (1, 1)
    sig = punzi_imp(eff_i, B, a=5)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi_imp a=5")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    plt.tight_layout()
    plt.show()
# Out:
# Results for SUEP-m125-darkPho_2018
# Results for SUEP-m400-darkPho_2018
# Results for SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018
# Results for SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018

# %%
# Significance scans using fit extrapolations
for signal in signals:
    print(f"Results for {signal}")
    s_i = S[signal]
    eff_i = S[signal]/S_tot[signal]
    fig, axs = plt.subplots(2, 3, figsize=(30, 20))
    
    #sig = S_over_SB(s_i, B)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[0, 0])
    #axs[0, 0].set_xlabel('l_muon_iso cut')
    #axs[0, 0].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_over_SB")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    #sig = S_12(s_i, B)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[0, 1])
    #axs[0, 1].set_xlabel('l_muon_iso cut')
    #axs[0, 1].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_12")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 0)
    sig = asimov_sig(s_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("asimov")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    #sig = S_over_BdB(s_i, B, deltaB2)
    #cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[1, 0])
    #axs[1, 0].set_xlabel('l_muon_iso cut')
    #axs[1, 0].set_ylabel('av_muon_pt cut')
    #cbar.cbar.set_label("S_over_BdB")
    #max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    #plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 1)
    sig = punzi(eff_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (0, 2)
    sig = punzi_imp(eff_i, B)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi_imp")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (1, 0)
    sig = punzi(eff_i, B, a=5)
    cbar = hep.hist2dplot(sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx])
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi a=5")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    idx = (1, 1)
    sig = punzi_imp(eff_i, B, a=5)
    cbar = hep.hist2dplot(
        sig, xbins=lead_interiso_cut, ybins=av_muon_pt_cut, ax=axs[idx], vmin=0.0, vmax=0.66*np.max(sig, axis=None)
    )
    axs[idx].set_xlabel('l_muon_iso cut')
    axs[idx].set_ylabel('av_muon_pt cut')
    cbar.cbar.set_label("punzi_imp a=5")
    max_i, max_j = np.unravel_index(np.argmax(sig, axis=None), sig.shape)
    plt.plot(lead_interiso_cut[max_i], av_muon_pt_cut[max_j], color='r', marker='P', markersize=20)
    
    plt.tight_layout()
    plt.show()
# Out:
# Results for SUEP-m125-darkPho_2018
# Results for SUEP-m400-darkPho_2018
# Results for SUEP_mMed-125_mDark-8_temp-32_decay-darkPho_2018
# Results for SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018

# %%
# Total B after cuts
cbar = hep.hist2dplot(B, xbins=lead_interiso_cut, ybins=av_muon_pt_cut)#, norm=matplotlib.colors.LogNorm())
plt.xlabel('l_muon_iso cut')
plt.ylabel('av_muon_pt cut')
cbar.cbar.set_label("B")

# %%
cbar = hep.hist2dplot(
    S['SUEP_mMed-125_mDark-8_temp-32_decay-darkPhoHad_2018'], 
    xbins=lead_interiso_cut, 
    ybins=av_muon_pt_cut,
    norm=matplotlib.colors.LogNorm()
)
plt.xlabel('l_muon_iso cut')
plt.ylabel('av_muon_pt cut')
cbar.cbar.set_label("S")

# %%
cbar = hep.hist2dplot(
    h_tot[0.5j:3j, :25j, ::sum, 6j::sum],
    #norm=matplotlib.colors.LogNorm()
)
plt.xlabel('l_muon_iso')
plt.ylabel('av_muon_pt')
#plt.xscale('log')
#plt.yscale('log')
cbar.cbar.set_label("B")

# %%
# Best seems to be (1.1, 16) ??? <–––– this is it for now

# %%
# or maybe (1.0, 15) after the extrapolations...

# %% [markdown]
# Slightly different best outcomes according to the used method. The optimum should be in the following ranges:
# - av_pt in (15,16)
# - interiso in (1.0, 1.25)

# %%
1
# Out:
# 1
