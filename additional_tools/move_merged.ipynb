# %%
import os
import glob
import numpy as np

# %%
base_dir = "/mnt/T3_US_MIT/hadoop/scratch/lavezzo/SUEP/scout/"
out_dir = "/data/submit/lavezzo/scout/"
if not os.path.isdir(out_dir): os.system("mkdir " + out_dir)
subdirs = os.listdir(base_dir)
for subdir in subdirs:
    if not os.path.isdir(out_dir + subdir):
        os.system("mkdir " + out_dir + subdir)
        os.system("mkdir " + out_dir + subdir+ "/merged/ ")
    #print("xrdcp -r root://t3serv017.mit.edu//scratch/lavezzo/SUEP/scout/"+subdir + "/merged/ " + out_dir+subdir+ "/merged/")
    os.system("xrdcp -r root://t3serv017.mit.edu//scratch/lavezzo/SUEP/scout/"+subdir+"/merged/ " + out_dir+subdir)
# Out:
# [928.1MB/928.1MB][100%][==================================================][46.41MB/s]
# Job: 1/49
# Source: root://t3serv017.mit.edu:1094//scratch/lavezzo/SUEP/scout/ScoutingPFHT+Run2018A-v1+RAW/merged///ScoutingPFHT+Run2018A-v1+RAW_merged_0.hdf5
# Target: file://localhost/data/submit/lavezzo/scout/ScoutingPFHT+Run2018A-v1+RAW//merged//ScoutingPFHT+Run2018A-v1+RAW_merged_0.hdf5
# [0B/0B][100%][==================================================][0B/s]
# Job: 2/49
# Source: root://t3serv017.mit.edu:1094//scratch/lavezzo/SUEP/scout/ScoutingPFHT+Run2018A-v1+RAW/merged///ScoutingPFHT+Run2018A-v1+RAW_merged_1.hdf5
# Target: file://localhost/data/submit/lavezzo/scout/ScoutingPFHT+Run2018A-v1+RAW//merged//ScoutingPFHT+Run2018A-v1+RAW_merged_1.hdf5
# [0B/0B][100%][==================================================][0B/s]
# Job: 3/49
# Source: root://t3serv017.mit.edu:1094//scratch/lavezzo/SUEP/scout/ScoutingPFHT+Run2018A-v1+RAW/merged///ScoutingPFHT+Run2018A-v1+RAW_merged_10.hdf5
# ...
