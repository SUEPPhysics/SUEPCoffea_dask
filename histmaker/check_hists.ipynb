# %%
import sys
sys.path.append('..')
import mplhep as hep
from plotting.plot_utils import openHistFile
import matplotlib.pyplot as plt

# %%
f = openHistFile("/ceph/submit/data/user/l/lavezzo/SUEP/outputs//debug/SUEP_mS125.000_mPhi3.000_T3.000_modegeneric.pkl")

# %%
print(f[0].keys())
# Out:
# dict_keys([])
